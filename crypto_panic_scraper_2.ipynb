# %%
import requests
import pandas as pd
import datetime
import config
import time
from datetime import datetime, timedelta
#from transformers import PegasusTokenizer, PegasusForConditionalGeneration
import torch
from bs4 import BeautifulSoup
import re
import feedparser
from readability import Document
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# main_script.py
import config

# %%
model_name = "ProsusAI/finbert"
tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")
model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert")

# %%
# Access the API key
api_key = config.API_KEY

global_api_rate_delay = .2  # All API methods are rate limited per IP at 5req/sec.

def make_url(api_key, filter=None, currencies=None, kind=None, region=None, page=None):
    """Handle of URL variables for API POST."""
    url = f'https://cryptopanic.com/api/v1/posts/?auth_token={api_key}'

    if currencies:
        if len(currencies.split(',')) <= 50:
            url += f"&currencies={currencies}"
        else:
            print("Warning: Max Currencies is 50")
            return

    if kind is not None and kind in ['news', 'media']:
        url += f"&kind={kind}"

    filters = ['rising', 'hot', 'bullish', 'bearish', 'important', 'saved', 'lol']
    if filter is not None and filter in filters:
        url += f"&filter={filter}"

    regions = ['en', 'de', 'es', 'fr', 'it', 'pt', 'ru']
    if region is not None and region in regions:
        url += f"&region={region}"

    if page is not None:
        url += f"&page={page}"

    return url


def get_page_json(url=None):
    """
    Get First Page.

    Returns Json.

    """
    time.sleep(global_api_rate_delay)
    if not url:
        url = "https://cryptopanic.com/api/v1/posts/?auth_token={}".format(config.API_KEY)
    page = requests.get(url)
    data = page.json()
    return data


def get_pages_list_json(lookback, url):
    """
    Get history of pages starting from page 1 to the lookback.

    Returns: List of Pages in Json format

    """
    pages_list_json = [get_page_json(url)]

    for i in range(lookback):
        pages_list_json.append(get_page_json(pages_list_json[i]["next"]))

    return pages_list_json


def get_df(data):
    """Return pandas DF."""
    # Ensure that data is a list of dictionaries
    if not all(isinstance(item, dict) for item in data):
        raise ValueError("Data must be a list of dictionaries")
    df = pd.DataFrame(data)
    try:
        df['created_at'] = pd.to_datetime(df['created_at'])
    except Exception as e:
        print(f"An error occurred: {e}")
    return df

def concatenate_pages(pages_list):
    """Concatenate Pages into one Dataframe."""
    # Ensure that pages_list is a list of lists of dictionaries
    if not all(isinstance(page, list) and all(isinstance(item, dict) for item in page) for page in pages_list):
        raise ValueError("Pages list must be a list of lists of dictionaries")
    frames = [get_df(page) for page in pages_list]
    return pd.concat(frames, ignore_index=True)

def get_last_posts(api_key, number_of_posts=200):
    pages_list = []
    page = 1
    total_results = 0
    while total_results < number_of_posts:
        # Conditionally set the filter based on a condition (e.g., 'hot' or 'important')
        if total_results % 2 == 0:
            filter = 'important'
        else:
            filter = 'hot'
        
        url = make_url(api_key, filter=filter, currencies='BTC', page=page)
        
        data = get_page_json(url)
        page_results = data['results']
        pages_list.append(page_results)
        total_results += len(page_results)
        page += 1
        if 'next' not in data or not data['next']:
            break  # No more pages to fetch
    flat_list = [item for sublist in pages_list for item in sublist]
    flat_list = flat_list[:number_of_posts]
    return [flat_list]

# Get the last 200 posts
pages_list = get_last_posts(api_key, number_of_posts=200)
df_last_200_posts = concatenate_pages(pages_list)
print(df_last_200_posts.head())
# Out:
#    kind           domain                                              votes  \
# 0  news     zycrypto.com  {'negative': 1, 'positive': 6, 'important': 4,...
# 1  news   bitcoinist.com  {'negative': 2, 'positive': 11, 'important': 8...
# 2  news  coinpaprika.com  {'negative': 6, 'positive': 8, 'important': 5,...
# 3  news      newsbtc.com  {'negative': 6, 'positive': 17, 'important': 5...
# 4  news     zycrypto.com  {'negative': 1, 'positive': 31, 'important': 2...
#
#                                               source  \
# 0  {'title': 'ZyCrypto', 'region': 'en', 'domain'...
# 1  {'title': 'Bitcoinist', 'region': 'en', 'domai...
# 2  {'title': 'coinpaprika', 'region': 'en', 'doma...
# 3  {'title': 'NewsBTC', 'region': 'en', 'domain':...
# 4  {'title': 'ZyCrypto', 'region': 'en', 'domain'...
#
#                                                title          published_at  \
# 0  XRP, Ether, Solana, Cardano, Shiba Inu Brace F...  2023-12-07T19:00:42Z
# 1  BREAKING: Spot Bitcoin ETF ‘May Be Approved So...  2023-12-07T14:08:55Z
# 2  Experts Find a Possible Kill Switch in BlackRo...  2023-12-06T08:37:26Z
# 3  ADA Price Claims $0.40 And Recovery Could Soon...  2023-12-06T06:28:14Z
# 4  Qatar Sovereign Wealth Fund Is Reportedly Read...  2023-12-05T16:18:03Z
#
#                                                 slug  \
# 0  XRP-Ether-Solana-Cardano-Shiba-Inu-Brace-For-T...
# 1  BREAKING-Spot-Bitcoin-ETF-May-Be-Approved-Soon...
# 2  Experts-Find-a-Possible-Kill-Switch-in-BlackRo...
# 3  ADA-Price-Claims-040-And-Recovery-Could-Soon-T...
# 4  Qatar-Sovereign-Wealth-Fund-Is-Reportedly-Read...
#
#                                           currencies        id  \
# 0  [{'code': 'BTC', 'title': 'Bitcoin', 'slug': '...  19093586
# 1  [{'code': 'BTC', 'title': 'Bitcoin', 'slug': '...  19092796
# 2  [{'code': 'BTC', 'title': 'Bitcoin', 'slug': '...  19088746
# 3  [{'code': 'BTC', 'title': 'Bitcoin', 'slug': '...  19088450
# 4  [{'code': 'BTC', 'title': 'Bitcoin', 'slug': '...  19087026
#
#                                                  url                created_at
# 0  https://cryptopanic.com/news/19093586/XRP-Ethe... 2023-12-07 19:00:42+00:00
# 1  https://cryptopanic.com/news/19092796/BREAKING... 2023-12-07 14:08:55+00:00
# 2  https://cryptopanic.com/news/19088746/Experts-... 2023-12-06 08:37:26+00:00
# 3  https://cryptopanic.com/news/19088450/ADA-Pric... 2023-12-06 06:28:14+00:00
# 4  https://cryptopanic.com/news/19087026/Qatar-So... 2023-12-05 16:18:03+00:00

# %%
# Transform the DataFrame into a list of dictionaries
articles_list = []
for _, row in df_last_200_posts.iterrows():
    article_dict = {
        'title': row['title'],
        'link': row['url'],  # Assuming 'url' is the link to the full article
        'published': row['created_at'],  # 'published_at' could also be used
        'summary': row['slug']  # Assuming you want to use the title as a summary, adjust as needed
        # If you have a summary column you can replace 'title' with the actual summary column name
    }
    articles_list.append(article_dict)

# Now articles_list is in the same format as thedefiant_articles
# You can print to confirm
for article in articles_list[:5]:  # Just print the first 5 for brevity
    print(f"Title: {article['title']}")
    print(f"Link: {article['link']}")
    print(f"Published: {article['published']}")
    print(f"Summary: {article['summary']}")
    print('---')
# Out:
# Title: XRP, Ether, Solana, Cardano, Shiba Inu Brace For Trillion-Dollar Storm As Spot Bitcoin ETF Finally Draws Near
# Link: https://cryptopanic.com/news/19093586/XRP-Ether-Solana-Cardano-Shiba-Inu-Brace-For-Trillion-Dollar-Storm-As-Spot-Bitcoin-ETF-Finally-Draws-Near
# Published: 2023-12-07 19:00:42+00:00
# Summary: XRP-Ether-Solana-Cardano-Shiba-Inu-Brace-For-Trillion-Dollar-Storm-As-Spot-Bitcoin-ETF-Finally-Draws-Near
# ---
# Title: BREAKING: Spot Bitcoin ETF ‘May Be Approved Soon’ – Reuters
# Link: https://cryptopanic.com/news/19092796/BREAKING-Spot-Bitcoin-ETF-May-Be-Approved-Soon-Reuters
# Published: 2023-12-07 14:08:55+00:00
# Summary: BREAKING-Spot-Bitcoin-ETF-May-Be-Approved-Soon-Reuters
# ---
# Title: Experts Find a Possible Kill Switch in BlackRock’s Updated ETF
# Link: https://cryptopanic.com/news/19088746/Experts-Find-a-Possible-Kill-Switch-in-BlackRocks-Updated-ETF
# Published: 2023-12-06 08:37:26+00:00
# Summary: Experts-Find-a-Possible-Kill-Switch-in-BlackRocks-Updated-ETF
# ---
# Title: ADA Price Claims $0.40 And Recovery Could Soon Turn Into Rally
# Link: https://cryptopanic.com/news/19088450/ADA-Price-Claims-040-And-Recovery-Could-Soon-Turn-Into-Rally
# Published: 2023-12-06 06:28:14+00:00
# Summary: ADA-Price-Claims-040-And-Recovery-Could-Soon-Turn-Into-Rally
# ---
# Title: Qatar Sovereign Wealth Fund Is Reportedly Ready To Splash A Jaw-Dropping $500 Billion On Bitcoin
# Link: https://cryptopanic.com/news/19087026/Qatar-Sovereign-Wealth-Fund-Is-Reportedly-Ready-To-Splash-A-Jaw-Dropping-500-Billion-On-Bitcoin
# Published: 2023-12-05 16:18:03+00:00
# Summary: Qatar-Sovereign-Wealth-Fund-Is-Reportedly-Ready-To-Splash-A-Jaw-Dropping-500-Billion-On-Bitcoin
# ---

# %%
from bs4 import BeautifulSoup
import requests

def get_article_content(url):
    response = requests.get(url)
    if response.ok:
        # Parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find the meta tag with the name attribute 'description'
        meta_description = soup.find('meta', attrs={'name': 'description'}) or soup.find('meta', attrs={'property': 'og:description'})
        
        # Extract the content attribute from the meta tag
        description = meta_description['content'] if meta_description else ''
        
        return description
    else:
        return 'Content not found or request failed.'

#  `df_last_200_posts` of the DataFrame containing articles
articles_list = []
for _, row in df_last_200_posts.iterrows():
    article_url = row['url']
    article_description = get_article_content(article_url)  # Retrieve the description
    article_dict = {
        'title': row['title'],
        'link': article_url,
        'published': row['created_at'],
        'summary': row['slug'],  # Or replace with the column that contains the actual summary
        'description': article_description  # Adding the retrieved description
    }
    articles_list.append(article_dict)

# Print the articles to confirm
for article in articles_list[:5]:  # Just print the first 5 for brevity
    print(f"Title: {article['title']}")
    print(f"Link: {article['link']}")
    print(f"Published: {article['published']}")
    print(f"Summary: {article['summary']}")
    print(f"Description: {article['description']}")
    print('---')
# Out:
# Title: XRP, Ether, Solana, Cardano, Shiba Inu Brace For Trillion-Dollar Storm As Spot Bitcoin ETF Finally Draws Near
# Link: https://cryptopanic.com/news/19093586/XRP-Ether-Solana-Cardano-Shiba-Inu-Brace-For-Trillion-Dollar-Storm-As-Spot-Bitcoin-ETF-Finally-Draws-Near
# Published: 2023-12-07 19:00:42+00:00
# Summary: XRP-Ether-Solana-Cardano-Shiba-Inu-Brace-For-Trillion-Dollar-Storm-As-Spot-Bitcoin-ETF-Finally-Draws-Near
# Description: ...detailed the potential that a spot Bitcoin ETF can have on the Bitcoin, XRP, Ethereum, Solana, Cardano, Shiba Inu markets.
# ---
# Title: BREAKING: Spot Bitcoin ETF ‘May Be Approved Soon’ – Reuters
# Link: https://cryptopanic.com/news/19092796/BREAKING-Spot-Bitcoin-ETF-May-Be-Approved-Soon-Reuters
# Published: 2023-12-07 14:08:55+00:00
# Summary: BREAKING-Spot-Bitcoin-ETF-May-Be-Approved-Soon-Reuters
# Description: According to Reuters, significant progress has been made in discussions between the US Securities and Exchange Commission (SEC) and asset managers over the potential approval of Bitcoin exchange-traded funds (ETFs). “Discussions between the US securities regulator and asset managers hoping to...
# ---
# Title: Experts Find a Possible Kill Switch in BlackRock’s Updated ETF
# Link: https://cryptopanic.com/news/19088746/Experts-Find-a-Possible-Kill-Switch-in-BlackRocks-Updated-ETF
# Published: 2023-12-06 08:37:26+00:00
# Summary: Experts-Find-a-Possible-Kill-Switch-in-BlackRocks-Updated-ETF
# Description: SEC closely works with Bitcoin ETF applicants, as experts discover and debate over a possible 'kill switch' in BlackRock's filing amid concerns of Bitcoin's security status.
# ---
# Title: ADA Price Claims $0.40 And Recovery Could Soon Turn Into Rally
# Link: https://cryptopanic.com/news/19088450/ADA-Price-Claims-040-And-Recovery-Could-Soon-Turn-Into-Rally
# Published: 2023-12-06 06:28:14+00:00
# Summary: ADA-Price-Claims-040-And-Recovery-Could-Soon-Turn-Into-Rally
# Description: Cardano (ADA) is gaining pace above the $0.40 resistance. ADA could rally if there is a clear move above the $0.432 and $0.450 resistance levels. ADA price is moving higher above the $0.400 pivot level. The price is trading above $0.415 and the 100 simple moving average (4 hours). There is a key...
# ---
# Title: Qatar Sovereign Wealth Fund Is Reportedly Ready To Splash A Jaw-Dropping $500 Billion On Bitcoin
# Link: https://cryptopanic.com/news/19087026/Qatar-Sovereign-Wealth-Fund-Is-Reportedly-Ready-To-Splash-A-Jaw-Dropping-500-Billion-On-Bitcoin
# Published: 2023-12-05 16:18:03+00:00
# Summary: Qatar-Sovereign-Wealth-Fund-Is-Reportedly-Ready-To-Splash-A-Jaw-Dropping-500-Billion-On-Bitcoin
# Description: The rumoured investment move is likely motivated by the potential for massive profits and the growing acceptance of bitcoin as a mainstream asset class.
# ---

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

# Define the device (either 'cuda' or 'cpu')
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

def analyze_sentiment(articles):
    sentiments = []
    for article in articles:
        # Assume that 'summary' is the key in the dictionary that contains the article text
        summary = article['description']

        # Encode and analyze the sentiment of the summary using your tokenizer and model
        inputs = tokenizer(summary, return_tensors='pt', truncation=True, padding=True)
        input_ids = inputs['input_ids'].to(device)
        attention_mask = inputs['attention_mask'].to(device)

        # Get the model's predictions
        with torch.no_grad():
            outputs = model(input_ids, attention_mask=attention_mask)
        
        # The output has the format (loss, logits) when labels are not provided
        logits = outputs.logits
        predictions = torch.softmax(logits, dim=-1)

        # Get the highest probability sentiment
        _, predicted_class = torch.max(predictions, dim=-1)
        sentiment_label = model.config.id2label[predicted_class.item()]

        # Reattach the date to the sentiment
        dated_sentiment = f"{article['published']} - {sentiment_label}"
        sentiments.append(dated_sentiment)
    return sentiments

# Assuming 'thedefiant_articles' is a list of article dictionaries
sentiments = analyze_sentiment(articles_list)

# Print the sentiment analysis results
for sentiment in sentiments:
    print(sentiment)
# Out:
# 2023-12-07 19:00:42+00:00 - neutral
# 2023-12-07 14:08:55+00:00 - positive
# 2023-12-06 08:37:26+00:00 - neutral
# 2023-12-06 06:28:14+00:00 - positive
# 2023-12-05 16:18:03+00:00 - positive
# 2023-12-05 07:36:58+00:00 - neutral
# 2023-12-05 03:51:16+00:00 - neutral
# 2023-12-04 22:20:04+00:00 - neutral
# 2023-12-04 19:18:45+00:00 - positive
# 2023-12-04 18:34:41+00:00 - neutral
# 2023-12-04 16:03:40+00:00 - positive
# 2023-12-04 14:50:05+00:00 - positive
# 2023-12-04 07:18:46+00:00 - positive
# 2023-12-03 22:39:58+00:00 - positive
# 2023-12-03 12:40:10+00:00 - neutral
# 2023-12-03 11:27:38+00:00 - positive
# 2023-12-03 09:24:15+00:00 - positive
# 2023-12-03 08:47:24+00:00 - negative
# 2023-12-02 21:55:46+00:00 - positive
# 2023-12-02 19:58:59+00:00 - positive
# 2023-12-02 15:11:03+00:00 - positive
# 2023-12-01 16:05:00+00:00 - negative
# 2023-12-01 14:31:18+00:00 - positive
# 2023-12-01 14:03:21+00:00 - neutral
# 2023-12-01 13:31:21+00:00 - neutral
# 2023-12-01 10:56:30+00:00 - positive
# 2023-12-01 10:15:16+00:00 - positive
# 2023-12-01 09:50:44+00:00 - positive
# 2023-12-01 09:33:11+00:00 - positive
# 2023-11-30 14:52:23+00:00 - positive
# 2023-11-30 14:11:12+00:00 - neutral
# 2023-11-30 12:58:24+00:00 - positive
# 2023-11-30 11:55:35+00:00 - positive
# 2023-11-30 11:08:46+00:00 - positive
# 2023-11-29 18:44:45+00:00 - positive
# 2023-11-29 18:22:08+00:00 - neutral
# 2023-11-29 16:20:46+00:00 - negative
# 2023-11-29 15:39:20+00:00 - neutral
# 2023-11-29 10:36:43+00:00 - negative
# 2023-11-28 23:45:24+00:00 - neutral
# 2023-11-28 16:51:08+00:00 - positive
# 2023-11-28 13:47:42+00:00 - positive
# 2023-11-28 09:38:29+00:00 - neutral
# 2023-11-28 09:31:51+00:00 - positive
# 2023-11-28 08:15:56+00:00 - negative
# 2023-11-28 07:34:43+00:00 - positive
# 2023-11-27 14:07:07+00:00 - positive
# 2023-11-27 12:39:51+00:00 - negative
# 2023-11-27 10:47:05+00:00 - negative
# 2023-11-27 09:45:19+00:00 - neutral
# 2023-11-26 10:51:55+00:00 - negative
# 2023-11-26 09:49:17+00:00 - neutral
# 2023-11-25 14:07:12+00:00 - neutral
# 2023-11-24 22:28:49+00:00 - positive
# 2023-11-24 15:40:05+00:00 - positive
# 2023-11-24 09:48:49+00:00 - positive
# 2023-11-23 12:21:18+00:00 - positive
# 2023-11-23 10:44:03+00:00 - positive
# 2023-11-23 09:40:50+00:00 - positive
# 2023-11-23 08:23:54+00:00 - positive
# 2023-11-22 23:37:34+00:00 - neutral
# 2023-11-22 18:54:05+00:00 - neutral
# 2023-11-22 14:10:40+00:00 - neutral
# 2023-11-22 12:36:37+00:00 - neutral
# 2023-11-22 10:51:21+00:00 - negative
# 2023-11-22 01:37:18+00:00 - neutral
# 2023-11-21 20:50:05+00:00 - neutral
# 2023-11-21 15:33:37+00:00 - positive
# 2023-11-21 15:30:00+00:00 - neutral
# 2023-11-21 15:14:05+00:00 - negative
# 2023-11-21 14:00:00+00:00 - positive
# 2023-11-20 19:05:54+00:00 - neutral
# 2023-11-20 15:39:10+00:00 - neutral
# 2023-11-20 15:39:00+00:00 - positive
# 2023-11-20 13:56:13+00:00 - positive
# 2023-11-20 12:00:06+00:00 - positive
# 2023-11-20 09:29:48+00:00 - neutral
# 2023-11-20 04:28:28+00:00 - neutral
# 2023-11-19 23:40:06+00:00 - neutral
# 2023-11-19 13:04:10+00:00 - negative
# 2023-11-19 10:48:10+00:00 - positive
# 2023-11-18 11:20:40+00:00 - neutral
# 2023-11-18 09:22:41+00:00 - positive
# 2023-11-18 07:24:47+00:00 - positive
# 2023-11-17 23:00:59+00:00 - positive
# 2023-11-17 17:47:21+00:00 - neutral
# 2023-11-17 17:13:05+00:00 - positive
# 2023-11-17 14:38:43+00:00 - negative
# 2023-11-17 11:22:11+00:00 - positive
# 2023-11-17 09:56:58+00:00 - positive
# 2023-11-16 21:18:11+00:00 - positive
# 2023-11-16 12:30:00+00:00 - positive
# 2023-11-16 11:27:27+00:00 - negative
# 2023-11-15 13:15:29+00:00 - positive
# 2023-11-15 10:25:03+00:00 - positive
# 2023-11-14 19:09:07+00:00 - neutral
# 2023-11-14 18:14:06+00:00 - neutral
# 2023-11-14 14:31:47+00:00 - negative
# 2023-11-14 13:35:34+00:00 - positive
# 2023-11-13 19:10:06+00:00 - positive
# 2023-11-13 11:40:32+00:00 - negative
# 2023-11-13 10:43:41+00:00 - positive
# 2023-11-13 09:44:26+00:00 - neutral
# 2023-11-13 07:10:29+00:00 - neutral
# 2023-11-12 18:05:00+00:00 - positive
# 2023-11-12 16:56:08+00:00 - positive
# 2023-11-12 14:15:12+00:00 - positive
# 2023-11-12 09:18:34+00:00 - neutral
# 2023-11-12 08:52:40+00:00 - positive
# 2023-11-12 07:00:59+00:00 - negative
# 2023-11-11 16:29:34+00:00 - positive
# 2023-11-11 12:24:06+00:00 - positive
# 2023-11-10 09:30:58+00:00 - neutral
# 2023-11-09 15:48:51+00:00 - positive
# 2023-11-09 15:38:14+00:00 - neutral
# 2023-11-09 15:23:32+00:00 - positive
# 2023-11-09 15:07:04+00:00 - neutral
# 2023-11-09 11:19:18+00:00 - neutral
# 2023-11-09 09:43:05+00:00 - positive
# 2023-11-09 09:34:03+00:00 - neutral
# 2023-11-09 07:58:21+00:00 - positive
# 2023-11-08 22:14:12+00:00 - neutral
# 2023-11-08 21:35:33+00:00 - positive
# 2023-11-08 20:51:28+00:00 - neutral
# 2023-11-08 03:41:36+00:00 - positive
# 2023-11-07 20:47:27+00:00 - neutral
# 2023-11-07 14:37:30+00:00 - positive
# 2023-11-07 14:01:42+00:00 - positive
# 2023-11-07 11:10:35+00:00 - positive
# 2023-11-07 07:59:32+00:00 - negative
# 2023-11-06 11:16:35+00:00 - neutral
# 2023-11-06 10:32:44+00:00 - positive
# 2023-11-05 18:52:57+00:00 - negative
# 2023-11-05 13:59:56+00:00 - negative
# 2023-11-05 13:59:04+00:00 - positive
# 2023-11-05 13:44:05+00:00 - neutral
# 2023-11-05 12:51:24+00:00 - positive
# 2023-11-04 19:39:04+00:00 - positive
# 2023-11-04 14:13:28+00:00 - positive
# 2023-11-04 11:27:54+00:00 - neutral
# 2023-11-04 09:32:20+00:00 - positive
# 2023-11-04 09:11:22+00:00 - positive
# 2023-11-03 20:00:57+00:00 - positive
# 2023-11-03 17:06:50+00:00 - positive
# 2023-11-03 12:31:07+00:00 - neutral
# 2023-11-03 10:42:41+00:00 - neutral
# 2023-11-02 20:31:15+00:00 - positive
# 2023-11-02 14:45:50+00:00 - positive
# 2023-11-02 14:30:01+00:00 - positive
# 2023-11-02 14:02:14+00:00 - positive
# 2023-11-02 12:31:44+00:00 - positive
# 2023-11-02 11:58:29+00:00 - positive
# 2023-11-02 10:25:36+00:00 - negative
# 2023-11-01 21:39:00+00:00 - positive
# 2023-11-01 10:18:37+00:00 - positive
# 2023-11-01 01:04:25+00:00 - neutral
# 2023-10-31 23:10:05+00:00 - neutral
# 2023-10-31 18:39:45+00:00 - positive
# 2023-10-31 15:33:42+00:00 - negative
# 2023-10-31 13:20:19+00:00 - positive
# 2023-10-31 11:33:57+00:00 - negative
# 2023-10-30 17:15:05+00:00 - neutral
# 2023-10-30 12:35:26+00:00 - positive
# 2023-10-30 12:28:07+00:00 - neutral
# 2023-10-30 09:43:11+00:00 - positive
# 2023-10-30 07:04:59+00:00 - neutral
# 2023-10-29 18:52:31+00:00 - positive
# 2023-10-29 13:02:45+00:00 - neutral
# 2023-10-29 03:26:59+00:00 - positive
# 2023-10-28 16:00:51+00:00 - positive
# 2023-10-28 11:13:36+00:00 - positive
# 2023-10-28 09:22:05+00:00 - neutral
# 2023-10-28 08:32:59+00:00 - neutral
# 2023-10-27 00:59:00+00:00 - positive
# 2023-10-26 16:30:20+00:00 - neutral
# 2023-10-26 13:03:37+00:00 - positive
# 2023-10-26 12:57:00+00:00 - positive
# 2023-10-26 12:24:59+00:00 - positive
# 2023-10-25 18:01:06+00:00 - neutral
# 2023-10-25 16:30:44+00:00 - positive
# 2023-10-25 09:40:19+00:00 - positive
# 2023-10-24 22:10:06+00:00 - negative
# 2023-10-24 17:30:00+00:00 - positive
# 2023-10-24 16:07:02+00:00 - neutral
# 2023-10-24 14:01:48+00:00 - positive
# 2023-10-24 09:49:56+00:00 - positive
# 2023-10-24 08:29:19+00:00 - positive
# 2023-10-23 22:14:25+00:00 - positive
# 2023-10-23 21:54:40+00:00 - neutral
# 2023-10-23 20:01:05+00:00 - positive
# 2023-10-23 18:53:04+00:00 - neutral
# 2023-10-23 14:28:51+00:00 - positive
# 2023-10-23 10:53:30+00:00 - negative
# 2023-10-23 09:44:31+00:00 - positive
# 2023-10-23 09:26:53+00:00 - positive
# 2023-10-23 05:39:30+00:00 - neutral
# 2023-10-22 23:15:00+00:00 - positive
# 2023-10-22 19:03:58+00:00 - neutral
# 2023-10-22 11:50:16+00:00 - positive
# 2023-10-22 10:33:41+00:00 - neutral

# %%
from transformers import pipeline

# Initialize the sentiment analysis pipeline with the FinBERT model
sentiment_analyzer = pipeline("text-classification", model="ProsusAI/finbert")

# Define the create_output_array function
def create_output_array(summaries, sentiment_scores, urls):
    output = []
    for i, summary in enumerate(summaries):
        date, summary_text = summary.split(' - ', 1)

        # Sentiment analysis using the pipeline
        sentiment_score = sentiment_scores[i][0]

        # Tokenize the summary text for sentiment analysis
        input_ids = tokenizer.encode(summary_text, add_special_tokens=True, return_tensors="pt")

        # Make sure the model is in evaluation mode
        model.eval()

        # Perform a forward pass to get the logits
        with torch.no_grad():
            logits = model(input_ids).logits

        # Add the sentiment logits to the output
        output_this = [
            date,
            summary_text,
            sentiment_score['label'],
            sentiment_score['score'],
            urls[i],
            logits.tolist()[0]  # Add logits to the output
        ]
        output.append(output_this)
    return output

# Run sentiment analysis on descriptions using the pipeline
summaries = [f"{article['published']} - {article['description']}" for article in articles_list]
sentiment_scores = [sentiment_analyzer(article['description']) for article in articles_list]

# Extract URLs from the articles list
cleaned_urls = [article['link'] for article in articles_list]

# Combine the summaries, sentiment scores, and URLs into one list
final_output = create_output_array(summaries, sentiment_scores, cleaned_urls)

# Insert headers at the beginning of the final output
final_output.insert(0, ['Date', 'Summary', 'Label', 'Confidence', 'URL', 'Logits'])

# Print or return the final output as needed
for line in final_output:
    print(line)
# Out:
# ['Date', 'Summary', 'Label', 'Confidence', 'URL', 'Logits']
# ['2023-12-07 19:00:42+00:00', '...detailed the potential that a spot Bitcoin ETF can have on the Bitcoin, XRP, Ethereum, Solana, Cardano, Shiba Inu markets.', 'neutral', 0.5697973370552063, 'https://cryptopanic.com/news/19093586/XRP-Ether-Solana-Cardano-Shiba-Inu-Brace-For-Trillion-Dollar-Storm-As-Spot-Bitcoin-ETF-Finally-Draws-Near', [1.0695269107818604, -2.694089889526367, 1.3734859228134155]]
# ['2023-12-07 14:08:55+00:00', 'According to Reuters, significant progress has been made in discussions between the US Securities and Exchange Commission (SEC) and asset managers over the potential approval of Bitcoin exchange-traded funds (ETFs). “Discussions between the US securities regulator and asset managers hoping to...', 'positive', 0.9129231572151184, 'https://cryptopanic.com/news/19092796/BREAKING-Spot-Bitcoin-ETF-May-Be-Approved-Soon-Reuters', [1.8770713806152344, -2.518946886062622, -0.6111675500869751]]
# ['2023-12-06 08:37:26+00:00', "SEC closely works with Bitcoin ETF applicants, as experts discover and debate over a possible 'kill switch' in BlackRock's filing amid concerns of Bitcoin's security status.", 'neutral', 0.42383378744125366, 'https://cryptopanic.com/news/19088746/Experts-Find-a-Possible-Kill-Switch-in-BlackRocks-Updated-ETF', [-0.581189751625061, 0.13773633539676666, 0.22762717306613922]]
# ['2023-12-06 06:28:14+00:00', 'Cardano (ADA) is gaining pace above the $0.40 resistance. ADA could rally if there is a clear move above the $0.432 and $0.450 resistance levels. ADA price is moving higher above the $0.400 pivot level. The price is trading above $0.415 and the 100 simple moving average (4 hours). There is a key...', 'positive', 0.5104328393936157, 'https://cryptopanic.com/news/19088450/ADA-Price-Claims-040-And-Recovery-Could-Soon-Turn-Into-Rally', [1.0118361711502075, -2.3678481578826904, 0.9339433312416077]]
# ['2023-12-05 16:18:03+00:00', 'The rumoured investment move is likely motivated by the potential for massive profits and the growing acceptance of bitcoin as a mainstream asset class.', 'positive', 0.7852809429168701, 'https://cryptopanic.com/news/19087026/Qatar-Sovereign-Wealth-Fund-Is-Reportedly-Ready-To-Splash-A-Jaw-Dropping-500-Billion-On-Bitcoin', [1.6206337213516235, -2.6434426307678223, 0.27111369371414185]]
# ['2023-12-05 07:36:58+00:00', "BlackRock files for an updated Bitcoin ETF, 'iShares Bitcoin Trust', joining major contenders, with Bloomberg analysts expecting SEC approval in Jan 2024.", 'neutral', 0.6291781067848206, 'https://cryptopanic.com/news/19085430/BlackRock-Files-For-an-Updated-Bitcoin-ETF', [0.9198473691940308, -2.5275187492370605, 1.4798732995986938]]
# ['2023-12-05 03:51:16+00:00', "BlackRock, the world's largest asset manager, has filed an updated application with the Securities and Exchange Commission (SEC) to launch a spot Bitcoin exchange-traded fund (ETF), according to a filing published today. The filing shows that BlackRock seeded the proposed ETF with a $100,000...", 'neutral', 0.7130000591278076, 'https://cryptopanic.com/news/19085135/BlackRock-seeded-its-Bitcoin-ETF-with-100K-in-October-new-SEC-filing-shows', [0.791764497756958, -2.537280321121216, 1.736964464187622]]
# ['2023-12-04 22:20:04+00:00', 'According to breaking information, BlackRock has submitted an updated version of the Bitcoin Spot ETF S-1 filing to the SEC. Bloomberg analysts had reported that negotiations between the SEC and BlackRock and other Bitcoin Spot ETF applicants were continuing. Similarly, Bitwise made a change in...', 'neutral', 0.8884456753730774, 'https://cryptopanic.com/news/19084772/BREAKING-BlackRock-Updates-Bitcoin-Spot-ETF-Application', [-0.35424643754959106, -1.3675732612609863, 2.030409812927246]]
# ['2023-12-04 19:18:45+00:00', "After years in the downturn market, El Salvador's Bitcoin holding has risen to a 3% gain over its investment.", 'positive', 0.9522010087966919, 'https://cryptopanic.com/news/19084426/El-Salvadors-Bitcoin-investment-hits-profits', [2.030831813812256, -1.9420123100280762, -1.4307960271835327]]
# ['2023-12-04 18:34:41+00:00', "Adam Back Predicts $100k Bitcoin by the halving a $1 Million Bitcoin this cycle top.✓ SUBSCRIBE - https://bit.ly/3QbgqTQ✓ LEAVE A LIKE & COMMENT LIMITED MERCH DROP► https://simplybitcoin.com/collections/allSPONSORS► Foundation's Bitcoin Hardware Wallet Passport:...", 'neutral', 0.8745796084403992, 'https://cryptopanic.com/news/19083598/Adam-Back-Predicts-700k-Bitcoin-this-Cycle-EP-880', [0.005011904984712601, -1.9376887083053589, 2.0810165405273438]]
# ['2023-12-04 16:03:40+00:00', "The surge in Bitcoin's value is part of a staggering performance throughout 2023, where the cryptocurrency has more than doubled in price, rebounding over...", 'positive', 0.9506396651268005, 'https://cryptopanic.com/news/19083976/Bitcoin-Bull-Calls-220000-All-Time-High-As-Ether-Shiba-Inu-Cardano-Solana-XRP-See-Crazy-Momentum', [2.0313663482666016, -1.5213072299957275, -1.7289941310882568]]
# ['2023-12-04 14:50:05+00:00', "El Salvador's Bitcoin investment is profitable by over $3 million following the latest upswing in the cryptocurrency's price.", 'positive', 0.9478604793548584, 'https://cryptopanic.com/news/19083719/El-Salvadors-President-Says-No-Intention-to-Sell-as-BTC-Holdings-Turns-Profitable', [1.9763675928115845, -1.880141258239746, -1.4089781045913696]]
# ['2023-12-04 07:18:46+00:00', "Bitcoin's surge to $41K, the first in 18 months, shakes the derivatives market and boosts its dominance, with altcoins and meme coins also gaining.", 'positive', 0.9452611804008484, 'https://cryptopanic.com/news/19082400/Bitcoin-Breaks-41000-Level-Boosting-its-Market-Dominance', [1.9459279775619507, -1.7164497375488281, -1.488702654838562]]
# ['2023-12-03 22:39:58+00:00', 'Bitcoin is back above $40,000, continuing its recent rise amid anticipation over a potential spot ETF approval in the U.S. And ETH is up too.', 'positive', 0.9493371844291687, 'https://cryptopanic.com/news/19081950/Bitcoin-Hits-40000-for-First-Time-Since-April-2022', [1.997216820716858, -1.5516066551208496, -1.7074601650238037]]
# ['2023-12-03 12:40:10+00:00', 'Michael Saylor Sees Over $1.5 Billion Profit on His BTC Investments', 'neutral', 0.506486177444458, 'https://cryptopanic.com/news/19081284/Micheal-Saylor-Sees-over-15-Billion-Profit-on-his-BTC-Investments', [1.1601107120513916, -2.453428030014038, 1.2126561403274536]]
# ['2023-12-03 11:27:38+00:00', 'After Google released its advanced chatbot, which garnered attention for its artificial intelligence (AI) capabilities, the technology has rapidly showcased … Continued', 'positive', 0.6818995475769043, 'https://cryptopanic.com/news/19081231/Google-Bard-picks-5-cryptocurrencies-to-buy-in-December', [1.4871796369552612, -2.39672589302063, 0.6795669794082642]]
# ['2023-12-03 09:24:15+00:00', 'A prominent trader renowned for accurately predicting the peak of Bitcoin’s 2021 bull market has now projected a significant upswing for Bitcoin, suggesting that even the most steadfast bears might reconsider their stance. This analyst, known as Pentoshi, said on social platform X that the U.S....', 'positive', 0.625087320804596, 'https://cryptopanic.com/news/19081131/Bitcoin-Poised-for-Explosive-Rally-Analyst-Predicts-Imminent-Surge-to-45000', [0.5547475814819336, -0.37339353561401367, -1.0324947834014893]]
# ['2023-12-03 08:47:24+00:00', 'Ripple’s Chief Legal Officer, Stuart Alderoty, has highlighted concerning trends in the US Securities and Exchange Commission’s (SEC) approach toward defending actions taken against cryptocurrency firms. Alderoty emphasized instances where different courts have criticized the regulatory body’s...', 'negative', 0.583351194858551, 'https://cryptopanic.com/news/19081095/SEC-Grapples-With-Judicial-Criticism-in-Ripple-Case-Inconsistencies-Exposed', [-0.6955400705337524, 0.828545093536377, 0.12819799780845642]]
# ['2023-12-02 21:55:46+00:00', 'Bitcoin hits a new high since April 2022, crossing $39,000 amid anticipation of ETF approvals and global market influences.', 'positive', 0.9381659626960754, 'https://cryptopanic.com/news/19080740/Bitcoin-Crosses-39000-as-ETF-Excitement-Rises', [1.8970184326171875, -1.8392215967178345, -1.2715007066726685]]
# ['2023-12-02 19:58:59+00:00', 'Chainlink also continues its run by jumping above $16.', 'positive', 0.903860867023468, 'https://cryptopanic.com/news/19080650/Over-100M-in-Liquidations-as-Bitcoin-BTC-Price-Soars-to-40K', [1.819908857345581, -2.0876104831695557, -0.6303096413612366]]
# ['2023-12-02 15:11:03+00:00', 'Amid a recent surge of optimism within the cryptocurrency sector, pseudonymous crypto trader The Flow Horse has projected a significant rise in the value of Bitcoin (CRYPTO: BTC). read more', 'positive', 0.7253322601318359, 'https://cryptopanic.com/news/19080347/Bitcoin-Set-To-Break-40000-Barrier-Says-Crypto-Expert-It-Looks-Like-It-Is-Just-A-Rising-Floor', [1.3817099332809448, -2.497579574584961, 0.35452404618263245]]
# ['2023-12-01 16:05:00+00:00', 'Charles Hoskinson questions Bitcoin maximalists’ dismissive attitude towards altcoins.', 'negative', 0.8718141317367554, 'https://cryptopanic.com/news/19078628/Cardanos-Charles-Hoskinson-Contests-Bitcoin-Maxi-Narratives', [-1.545287847518921, 2.2369980812072754, 0.15164272487163544]]
# ['2023-12-01 14:31:18+00:00', 'After Bitcoin (BTC) crossed the massive psychological level at $38,000 and continued to advance, optimism has returned to the cryptocurrency … Continued', 'positive', 0.9408705234527588, 'https://cryptopanic.com/news/19078354/Bitcoin-to-the-moon-40000-around-the-corner-as-85-of-holders-in-profit', [1.9737011194229126, -1.872110366821289, -1.208930253982544]]
# ['2023-12-01 14:03:21+00:00', 'The cryptocurrency market holds an abundance of opportunities. While the focus commonly centers on major cryptos like Bitcoin (BTC) and … Continued', 'neutral', 0.613872230052948, 'https://cryptopanic.com/news/19078259/3-cryptocurrencies-under-1-to-buy-next-week', [1.0481019020080566, -2.6079370975494385, 1.5372270345687866]]
# ['2023-12-01 13:31:21+00:00', 'As the festive season approaches and the holiday shopping season is just around the corner, many are pondering the perfect … Continued', 'neutral', 0.8432077169418335, 'https://cryptopanic.com/news/19078162/Is-Bitcoin-a-good-Christmas-present', [-0.7480302453041077, -0.2643106281757355, 1.8982356786727905]]
# ['2023-12-01 10:56:30+00:00', 'As optimism returns to the cryptocurrency market with its representative asset, Bitcoin (BTC), crossing the threshold at $38,000 and establishing … Continued', 'positive', 0.9378317594528198, 'https://cryptopanic.com/news/19077708/Whats-next-for-Bitcoin-as-21k-blocks-left-to-be-mined-until-halving', [2.0560102462768555, -2.2854530811309814, -0.8763371706008911]]
# ['2023-12-01 10:15:16+00:00', 'MicroStrategy is continuing to show its bullish stance on Bitcoin (BTC) by stacking up its holdings of the leading crypto asset by market cap. In a post on the social media platform X, MicroStrategy co-founder and executive chairman Michael Saylor says the business intelligence firm bought an...', 'positive', 0.7620709538459778, 'https://cryptopanic.com/news/19077593/MicroStrategy-Doubles-Down-on-Bitcoin-Acquires-593300000-Worth-of-BTC-As-Top-Crypto-Asset-Trades-Sideways', [1.6196606159210205, -2.523684024810791, 0.4034263789653778]]
# ['2023-12-01 09:50:44+00:00', 'Bitcoin starts December strong, with prices over $38,000, triggering $36.88M in liquidations and a 4% rise in futures and options interest.', 'positive', 0.9349622130393982, 'https://cryptopanic.com/news/19077512/Traders-Lose-368-Million-as-Bitcoin-Starts-December-Strong', [1.872830867767334, -1.2675055265426636, -1.7655906677246094]]
# ['2023-12-01 09:33:11+00:00', 'Bitcoin (BTC) has commenced December with a surge, catapulting above the $38,000 mark and signalling promising year-end highs.', 'positive', 0.9456603527069092, 'https://cryptopanic.com/news/19077478/Bitcoin-Enters-December-Eying-40k-As-XRP-Ether-Cardano-Solana-Shiba-Inu-Look-To-Herald-Year-End-Highs', [1.9535729885101318, -1.6337116956710815, -1.5600526332855225]]
# ['2023-11-30 14:52:23+00:00', 'The general cryptocurrency market has been on a bullish momentum in recent weeks, led by Bitcoin (BTC), with anticipation that … Continued', 'positive', 0.9464415907859802, 'https://cryptopanic.com/news/19075467/Crypto-market-in-limbo-as-technicals-hint-Bulls-vs-Bears-fight-ahead', [1.950217604637146, -1.6365532875061035, -1.5936367511749268]]
# ['2023-11-30 14:11:12+00:00', "Business intelligence firm MicroStrategy announced today that it has purchased an additional 16,130 Bitcoins for approximately $593.3 million. MicroStrategy's Bitcoin holdings now stand at 174,530 Bitcoins acquired for $5.28 billion at an average price of just over $30,000 per...", 'neutral', 0.9127723574638367, 'https://cryptopanic.com/news/19075335/MicroStrategy-Buys-593-Million-Worth-of-Bitcoin', [-0.171672061085701, -1.9812861680984497, 2.327913284301758]]
# ['2023-11-30 12:58:24+00:00', 'As the anticipation intensifies surrounding the possible approval of the first spot Bitcoin (BTC) exchange-traded fund (ETF) by the United … Continued', 'positive', 0.850841224193573, 'https://cryptopanic.com/news/19075046/Bitcoin-mining-stocks-an-opportunity-everybody-seems-to-be-missing', [1.8336864709854126, -2.5960276126861572, 0.02206764742732048]]
# ['2023-11-30 11:55:35+00:00', "ProShares' Bitcoin ETF (BITO) hits $1.47B, showing rising interest among investors as they await U.S. approval for Bitcoin spot ETFs.", 'positive', 0.9483057260513306, 'https://cryptopanic.com/news/19074866/Investors-Interest-in-Bitcoin-Rise-as-ProShares-Bitcoin-ETF-Hits-147B', [1.9531896114349365, -1.842180848121643, -1.4876528978347778]]
# ['2023-11-30 11:08:46+00:00', 'Despite the temporary setback, Bitcoin (BTC) has briefly managed to break the barrier at $38,000 a couple of times in … Continued', 'positive', 0.8299803137779236, 'https://cryptopanic.com/news/19074701/Bitcoin-pre-and-post-halving-bull-run-to-kick-BTC-toward-250000', [1.3447433710098267, -0.4532712697982788, -1.8938140869140625]]
# ['2023-11-29 18:44:45+00:00', 'British multinational bank Standard Chartered has reiterated that Bitcoin is well on track to reach the $100,000 level by next year as the top cryptocurrency broke above $38,000 on Nov. 29.', 'positive', 0.9198119044303894, 'https://cryptopanic.com/news/19072992/Standard-Chartered-Sees-Bitcoin-Breaking-2024-With-A-Mind-Blowing-BTC-Moonshot-To-100000-Price', [1.9123356342315674, -2.2144641876220703, -0.732114315032959]]
# ['2023-11-29 18:22:08+00:00', 'According to the details shared by the Bloomberg analyst, the SEC and BlackRock renegotiated for the Bitcoin Spot ETF. Continue Reading: BlackRock Officials Met With SEC Officials Again Today For Bitcoin Spot ETF! Here Are The Meeting Details', 'neutral', 0.9314057230949402, 'https://cryptopanic.com/news/19072956/BlackRock-Officials-Met-With-SEC-Officials-Again-Today-For-Bitcoin-Spot-ETF-Here-Are-The-Meeting-Details', [-1.0798882246017456, -0.7589038610458374, 2.3950610160827637]]
# ['2023-11-29 16:20:46+00:00', 'The cryptocurrency market anticipates a potential bull market triggered by events such as Bitcoin halving and the approval of a … Continued', 'negative', 0.73747718334198, 'https://cryptopanic.com/news/19072608/Bloomberg-analyst-reaffirms-90-chance-of-Bitcoin-ETF-approval-in-January', [-0.9083749055862427, 1.3415189981460571, -0.042522769421339035]]
# ['2023-11-29 15:39:20+00:00', 'Almost since its inception, the crypto market has been marked by its significant and often sudden price movements. Various cryptocurrencies … Continued', 'neutral', 0.5505272746086121, 'https://cryptopanic.com/news/19072475/Expert-crypto-predictions-Whats-next-in-2024', [-1.54121732711792, 1.126601219177246, 1.3965034484863281]]
# ['2023-11-29 10:36:43+00:00', 'The supply of Bitcoin (BTC) on cryptocurrency exchanges has hit its lowest amount in the past five years, as investors … Continued', 'negative', 0.9686519503593445, 'https://cryptopanic.com/news/19071367/Bitcoin-supply-on-exchanges-hits-lowest-in-5-years-Heres-why', [-1.7993344068527222, 2.959475040435791, -0.7791479825973511]]
# ['2023-11-28 23:45:24+00:00', 'Hoskinson said regulators could label Bitcoin and Ethereum as securities just as easily as ADA if they wanted to.', 'neutral', 0.9241880178451538, 'https://cryptopanic.com/news/19070354/Charles-Hoskinson-Pins-Bitcoin-Against-Cardano-in-Light-of-Securities-Discussion', [-0.9032568335533142, -1.0199910402297974, 2.233884811401367]]
# ['2023-11-28 16:51:08+00:00', 'Bitcoin experienced a turbulent start this month, plummeting over 5% on Tuesday following Changpeng Zhao’s (CZ) resignation as Binance CEO. However, the flagship cryptocurrency demonstrated remarkable resilience, surging to...', 'positive', 0.8278060555458069, 'https://cryptopanic.com/news/19069566/Bitcoin-Ether-Cardano-Shiba-Inu-XRP-Near-Bull-Breaking-Point-As-Tether-Whales-Inject-17-Billion', [1.483398199081421, -0.20859770476818085, -2.2521190643310547]]
# ['2023-11-28 13:47:42+00:00', 'Although its gains have slowed down in recent days, Bitcoin (BTC) is nonetheless trading above the psychologically important price level … Continued', 'positive', 0.7822940349578857, 'https://cryptopanic.com/news/19068946/Bitcoin-to-never-go-below-35k-ever-again-says-expert', [1.1494088172912598, -0.3376491069793701, -1.8022099733352661]]
# ['2023-11-28 09:38:29+00:00', 'With the holiday season almost upon us, Bitcoin (BTC) might be carrying gifts instead of Santa as it looks to … Continued', 'neutral', 0.854814887046814, 'https://cryptopanic.com/news/19068232/Machine-learning-algorithm-predicts-Bitcoin-price-for-Xmas-day', [-1.0052803754806519, -0.24316100776195526, 1.9127134084701538]]
# ['2023-11-28 09:31:51+00:00', 'Although things may not look as bright for Bitcoin (BTC) as the week begins, the flagship decentralized finance (DeFi) asset … Continued', 'positive', 0.9220925569534302, 'https://cryptopanic.com/news/19068233/Bitcoin-eyes-18-month-rally-amid-bullish-indicators', [1.6968801021575928, -1.8078049421310425, -1.2138941287994385]]
# ['2023-11-28 08:15:56+00:00', 'Charles Hoskinson, the founder of Cardano, recently unleashed a fervent critique of the US Securities and Exchange Commission (SEC) and raised questions about Bitcoin’s decentralization in a candid AMA session. Cardano Founder Blasts SEC And Bitcoin Hoskinson’s criticism was primarily aimed at...', 'negative', 0.4922500252723694, 'https://cryptopanic.com/news/19068042/Cardano-Founder-Rants-Bitcoin-Not-Decentralized-SEC-Crypto-Policy-Unfair', [-1.2673375606536865, 0.9584323167800903, 0.8788518309593201]]
# ['2023-11-28 07:34:43+00:00', 'Raoul Pal predicts a promising 2024 for Bitcoin, potentially outperforming tech stocks, backed by bullish market indicators and upcoming Bitcoin halving.', 'positive', 0.9526921510696411, 'https://cryptopanic.com/news/19067972/Buy-Bitcoin-6-Months-Before-Halving-Analysts-Suggest', [2.0596389770507812, -1.5830016136169434, -1.6922311782836914]]
# ['2023-11-27 14:07:07+00:00', 'So far, the pseudo-anonymity offered by cryptocurrencies has proven both a blessing and a curse. On the one hand, it … Continued', 'positive', 0.3703230023384094, 'https://cryptopanic.com/news/19066174/Tron-overtakes-BTC-as-Hamas-and-Hezbollahs-blockchain-of-choice', [-0.033753424882888794, -0.22718513011932373, -0.1658923625946045]]
# ['2023-11-27 12:39:51+00:00', 'Facing the turmoil of the largest cryptocurrency exchange, Binance, and recent rocky charts that have seen most crypto assets experience … Continued', 'negative', 0.9653599262237549, 'https://cryptopanic.com/news/19065888/ChatGPT-picks-5-cryptocurrencies-to-buy-for-December', [-1.5589900016784668, 2.778566360473633, -1.0017859935760498]]
# ['2023-11-27 10:47:05+00:00', 'Although the majority of assets in the cryptocurrency sector got off to a slow start this week, Bitcoin (BTC) could … Continued', 'negative', 0.8669947981834412, 'https://cryptopanic.com/news/19065610/Bitcoin-slicing-through-this-resistance-could-send-it-over-47k', [-0.40499231219291687, 1.7170615196228027, -1.6754496097564697]]
# ['2023-11-27 09:45:19+00:00', 'Amid his countless warnings of a looming financial crash, Robert Kiyosaki has shared more of his reasoning as to why … Continued', 'neutral', 0.7580741047859192, 'https://cryptopanic.com/news/19065459/Rich-Dad-R-Kiyosakis-stark-warning-Buy-Bitcoin-before-its-too-late', [-0.7945307493209839, 0.06133560836315155, 1.5575975179672241]]
# ['2023-11-26 10:51:55+00:00', 'As the cryptocurrency market anticipates a potential bull market, investors may consider accumulating Bitcoin (BTC) in preparation for it. A … Continued', 'negative', 0.6847181916236877, 'https://cryptopanic.com/news/19064026/Is-sub-40k-Bitcoin-a-bargain-Heres-what-the-analyst-says', [-0.5914542078971863, 0.9862325191497803, -0.3841779828071594]]
# ['2023-11-26 09:49:17+00:00', 'Former New York Stock Exchange (NYSE) President Tom Farley is the latest figure in the financial world to discuss the … Continued', 'neutral', 0.8879275918006897, 'https://cryptopanic.com/news/19063967/Former-NYSE-president-reveals-when-money-will-flood-into-crypto', [-0.48206964135169983, -0.7942091226577759, 2.1368820667266846]]
# ['2023-11-25 14:07:12+00:00', 'The cryptocurrency market is a realm teeming with opportunities. Although the limelight frequently falls on prominent cryptocurrencies such as Bitcoin … Continued', 'neutral', 0.6516344547271729, 'https://cryptopanic.com/news/19063152/3-cryptocurrencies-under-5-to-buy-next-week', [0.6447819471359253, -1.9319589138031006, 1.3442838191986084]]
# ['2023-11-24 22:28:49+00:00', 'Bitcoin (BTC) is currently dominated by bullish sentiments, with the leading cryptocurrency aiming to reclaim the $40,000 spot in pursuit … Continued', 'positive', 0.9253371953964233, 'https://cryptopanic.com/news/19062301/Conservative-Bitcoin-price-prediction-for-late-2025', [1.8141705989837646, -1.8877888917922974, -1.0680173635482788]]
# ['2023-11-24 15:40:05+00:00', 'Numerous cryptocurrencies, such as Bitcoin (BTC) and Ethereum (ETH), have been methodically challenging and surpassing new resistance levels amidst the … Continued', 'positive', 0.5671066641807556, 'https://cryptopanic.com/news/19061621/3-cryptos-to-buy-under-010-next-week', [0.5477481484413147, -0.026312902569770813, -1.061173677444458]]
# ['2023-11-24 09:48:49+00:00', 'As the cryptocurrency industry awaits a massive step toward the mainstream in the form of the United States Securities and … Continued', 'positive', 0.5715806484222412, 'https://cryptopanic.com/news/19060606/Spot-Bitcoin-ETF-approval-could-unlock-70-billion-capital-influx-data-shows', [1.3772848844528198, -2.6575522422790527, 1.0650997161865234]]
# ['2023-11-23 12:21:18+00:00', 'With the overall sentiment in the cryptocurrency sector becoming more optimistic and Bitcoin (BTC) reclaiming the significant price level of … Continued', 'positive', 0.9312966465950012, 'https://cryptopanic.com/news/19058672/Jim-Cramer-urges-viewers-to-just-buy-Bitcoin', [1.9060808420181274, -1.9238659143447876, -1.0492578744888306]]
# ['2023-11-23 10:44:03+00:00', 'As the sentiment in the general cryptocurrency sector has turned more positive and Bitcoin (BTC) returned to the psychologically important … Continued', 'positive', 0.951229989528656, 'https://cryptopanic.com/news/19058421/Whats-next-for-Bitcoin-as-85-of-BTC-holders-are-in-profit', [2.042215347290039, -2.0793204307556152, -1.3087399005889893]]
# ['2023-11-23 09:40:50+00:00', 'Amid heightened anticipation and excitement surrounding the possibility that the United States Securities and Exchange Commission (SEC) could approve the … Continued', 'positive', 0.7895660400390625, 'https://cryptopanic.com/news/19058201/SEC-Commissioner-No-reason-to-stand-in-the-way-of-spot-Bitcoin-ETF', [1.4449106454849243, -2.244558095932007, 0.024161895737051964]]
# ['2023-11-23 08:23:54+00:00', 'Record 70.35% of Bitcoin supply inactive for over a year, showing strong holder confidence despite market challenges.', 'positive', 0.9512900710105896, 'https://cryptopanic.com/news/19057955/Bitcoin-investors-Show-Confidence-As-7035-of-Bitcoin-Supply-Stays-Unmoved', [2.083059549331665, -2.112133502960205, -1.2373998165130615]]
# ['2023-11-22 23:37:34+00:00', 'Grayscale submitted an updated filing for its pending spot Bitcoin ETF to the U.S. Securities and Exchange Commission (SEC) on Nov. 22. The filing in question is an amended S-3 prospectus, a type of registration form used by firms that have previously met other reporting requirements. Bloomberg...', 'neutral', 0.9319800734519958, 'https://cryptopanic.com/news/19057410/Grayscale-files-updated-Bitcoin-ETF-prospectus-days-after-talks-with-US-SEC', [-0.9143691062927246, -1.0122262239456177, 2.3485569953918457]]
# ['2023-11-22 18:54:05+00:00', 'Bloomberg analysts revealed that BlackRock and the SEC met on Monday to discuss the Bitcoin Spot ETF product. Continue Reading: BlackRock and the SEC Recently Met for Bitcoin Spot ETF Approval, It Has Been Revealed', 'neutral', 0.8890572190284729, 'https://cryptopanic.com/news/19056989/BlackRock-and-the-SEC-Recently-Met-for-Bitcoin-Spot-ETF-Approval-It-Has-Been-Revealed', [-0.10722757875919342, -1.9903767108917236, 2.1155149936676025]]
# ['2023-11-22 14:10:40+00:00', 'As the cryptocurrency market braces for the next bull market, investors find themselves standing at a crossroads, facing the pivotal … Continued', 'neutral', 0.6624279618263245, 'https://cryptopanic.com/news/19056182/Bitcoin-or-altcoins-What-is-a-better-investment-for-the-next-bull-market', [-0.6369881629943848, 0.10231460630893707, 1.1667628288269043]]
# ['2023-11-22 12:36:37+00:00', 'One of Bitcoin’s (BTC) core value propositions is it being a censorship-resistance form of money, not subject to arbitrary rule-making. … Continued', 'neutral', 0.7483241558074951, 'https://cryptopanic.com/news/19055899/Third-largest-Bitcoin-mining-pool-likely-censored-OFAC-sanctioned-transactions', [0.7665936350822449, -2.5431392192840576, 1.8921624422073364]]
# ['2023-11-22 10:51:21+00:00', 'Although the cryptocurrency market has hit a rough spot following the news of Changpeng Zhao stepping down as Binance CEO … Continued', 'negative', 0.8960205316543579, 'https://cryptopanic.com/news/19055532/Whats-next-for-Bitcoin-as-it-forms-super-bullish-pattern', [-1.7027931213378906, 2.4344770908355713, 0.13268615305423737]]
# ['2023-11-22 01:37:18+00:00', 'The agency met with Grayscale Investments on Monday after a court issued a mandate last month to have the SEC re-review the ETF bid.', 'neutral', 0.615915060043335, 'https://cryptopanic.com/news/19054593/SEC-recently-met-with-Grayscale-for-spot-bitcoin-ETF-listing-memo-shows', [-0.1512274295091629, -0.36687928438186646, 0.9121410846710205]]
# ['2023-11-21 20:50:05+00:00', 'The big conference, where four important US government officials will make statements regarding cryptocurrency sanctions, has begun. Continue Reading: Conference Followed by the Entire Cryptocurrency World Has Begun: 4 Major US Government Officials Are Announcing Cryptocurrency Enforcements', 'neutral', 0.9080680012702942, 'https://cryptopanic.com/news/19054156/Conference-Followed-by-the-Entire-Cryptocurrency-World-Has-Begun-4-Major-US-Government-Officials-Are-Announcing-Cryptocurrency-Enforcements', [-0.9145031571388245, -0.8753259778022766, 2.0886950492858887]]
# ['2023-11-21 15:33:37+00:00', 'Phoenix Group, a Bitcoin (BTC) mining and colocation service provider based in Abu Dhabi, has made a significant mark by … Continued', 'positive', 0.937680721282959, 'https://cryptopanic.com/news/19053350/Abu-Dhabi-based-Bitcoin-miner-Phoenix-Group-raises-370-million-in-IPO', [2.061414957046509, -2.4469125270843506, -0.8309626579284668]]
# ['2023-11-21 15:30:00+00:00', 'Many are excited about the potential for a second Bitcoin President in Latin America, but there are reasons to be more skeptical and cautious before cheer leading.', 'neutral', 0.7681066393852234, 'https://cryptopanic.com/news/19053310/Mileis-Presidency-Implications-For-Argentina-El-Salvador-And-Bitcoin-Adoption', [0.07258429378271103, -1.7592124938964844, 1.4187633991241455]]
# ['2023-11-21 15:14:05+00:00', 'According to Bloomberg, the US Department of Justice will announce cryptocurrency enforcement actions today. BTC dropped to $36.00. Continue Reading: BREAKING! Cryptocurrency Announcement is Expected from the US Department of Justice! Bitcoin Reacted!', 'negative', 0.8800185918807983, 'https://cryptopanic.com/news/19053308/BREAKING-Cryptocurrency-Announcement-is-Expected-from-the-US-Department-of-Justice-Bitcoin-Reacted', [-1.463526725769043, 2.013850212097168, -0.2356552630662918]]
# ['2023-11-21 14:00:00+00:00', 'Global banks have begun actively integrating crypto assets into their financial operations, and XRP has been one of their top preferences. This news signifies a shift in the skepticism surrounding cryptocurrencies, revealing how some of the world’s leading banks seek to leverage XRP’s...', 'positive', 0.5254387855529785, 'https://cryptopanic.com/news/19053048/Global-Banks-Are-Betting-Big-On-XRP-Report-Shows', [0.7795213460922241, -2.054625988006592, 0.6103953719139099]]
# ['2023-11-20 19:05:54+00:00', 'The market for a spot Bitcoin (BTC) exchange-traded fund (ETF) could quickly turn into a “$100 billion juggernaut,” according to new estimates from Bloomberg Intelligence. Investment giant Galaxy Digital reportedly held a call earlier this month with roughly 300 investment professionals...', 'neutral', 0.7808284759521484, 'https://cryptopanic.com/news/19051010/100000000000-in-TradFi-Money-Waiting-for-Bitcoin-ETF-Approval-Says-Bloomberg-Intelligence-Analysts', [0.44777363538742065, -2.057401657104492, 1.7967724800109863]]
# ['2023-11-20 15:39:10+00:00', "Cathie Wood's ARK Invest has submitted an updated filing for its spot bitcoin exchange-traded fund (ETF), ignoring recent guidance from the Securities and Exchange Commission (SEC) to switch ETF proposals to cash creations rather than in-kind creations.ETFs can create or redeem shares to manage...", 'neutral', 0.9119412302970886, 'https://cryptopanic.com/news/19050524/ARK-Ignores-SEC-Advice-Refiles-In-Kind-Bitcoin-Spot-ETF', [-0.5140392184257507, -1.3685412406921387, 2.1780505180358887]]
# ['2023-11-20 15:39:00+00:00', 'Cryptocurrency funds have marked notable week of inflows, with Ethereum, Solana and other altcoins seeing substantial investment alongside Bitcoin', 'positive', 0.9475065469741821, 'https://cryptopanic.com/news/19050530/XRP-BTC-ETH-ADA-SOL-Funds-Attract-More-Inflows-Report', [1.977720856666565, -1.9424408674240112, -1.3587044477462769]]
# ['2023-11-20 13:56:13+00:00', 'The impending approval of Bitcoin (BTC) exchange-traded funds (ETF) generates significant excitement in a potential breakthrough for cryptocurrency on Wall … Continued', 'positive', 0.901706874370575, 'https://cryptopanic.com/news/19050173/Wall-Street-sees-100-billion-crypto-potential-amid-Bitcoin-ETF-hype', [1.8870079517364502, -2.482144832611084, -0.45280197262763977]]
# ['2023-11-20 12:00:06+00:00', 'After Bitcoin (BTC) friendly president-elect Javier Milei won the ballot in Argentina, Tesla (NASDAQ: TSLA) CEO Elon Musk praised his … Continued', 'positive', 0.8599990606307983, 'https://cryptopanic.com/news/19049839/Elon-Musk-predicts-prosperity-for-Argentina-with-new-pro-Bitcoin-president', [1.8147088289260864, -2.104848861694336, -0.1306072622537613]]
# ['2023-11-20 09:29:48+00:00', 'Amid his continuous warnings about the imminent financial collapse, particularly in the United States, the author of the best-selling personal … Continued', 'neutral', 0.6141567826271057, 'https://cryptopanic.com/news/19049498/Rich-Dad-R-Kiyosaki-Hyperinflation-led-to-Hitlers-rise-Bitcoin-is-best-defense', [-0.22577379643917084, -0.07535434514284134, 1.010227918624878]]
# ['2023-11-20 04:28:28+00:00', 'Cardano (ADA) is moving higher from the $0.350 support. ADA could rally if there is a clear move above the $0.388 and $0.395 resistance levels. ADA price is moving higher above the $0.375 pivot level. The price is trading above $0.380 and the 100 simple moving average (4 hours). There is a key...', 'neutral', 0.6160842180252075, 'https://cryptopanic.com/news/19049104/ADA-Price-Cardano-Breaking-This-Confluence-Resistance-Could-Restart-Rally', [0.6728852391242981, -2.2423181533813477, 1.198621153831482]]
# ['2023-11-19 23:40:06+00:00', 'Bitcoin supporter presidential candidate Javier Milei, who was left behind in the first round in Argentina, managed to win the elections in the second round. Continue Reading: JUST IN: Pro-Bitcoin Candidate Javier Milei Wins Election in Argentina, BTC Breaks $37,000', 'neutral', 0.7132458090782166, 'https://cryptopanic.com/news/19048931/JUST-IN-Pro-Bitcoin-Candidate-Javier-Milei-Wins-Election-in-Argentina-BTC-Breaks-37000', [-0.13290004432201385, -0.9392989277839661, 1.1474220752716064]]
# ['2023-11-19 13:04:10+00:00', 'As Bitcoin (BTC) maintains its position above the $30,000 mark, a prevalent question lingers among the crypto community and the … Continued', 'negative', 0.7348313331604004, 'https://cryptopanic.com/news/19048379/Should-you-buy-Bitcoin-while-it-is-above-30000', [-1.2054195404052734, 1.552835464477539, 0.3403405249118805]]
# ['2023-11-19 10:48:10+00:00', 'The current cryptocurrency market is witnessing a substantial surge, capturing the attention of investors. While cryptocurrencies like Bitcoin and Ethereum … Continued', 'positive', 0.9310742020606995, 'https://cryptopanic.com/news/19048255/3-cryptocurrencies-to-buy-under-10-next-week', [1.8928872346878052, -2.2270405292510986, -0.9581815004348755]]
# ['2023-11-18 11:20:40+00:00', 'Reading serves as a source of entertainment for me, and I spend numerous hours indulging in it. However, certain books … Continued', 'neutral', 0.9183471202850342, 'https://cryptopanic.com/news/19047131/3-lessons-I-have-learned-from-the-Bitcoin-Standard', [-0.6263805031776428, -1.2026022672653198, 2.239696502685547]]
# ['2023-11-18 09:22:41+00:00', 'Bitcoin (BTC) has recently struggled to surpass the $38,000 mark but maintains a comfortable position above the $35,000 support zone … Continued', 'positive', 0.9196136593818665, 'https://cryptopanic.com/news/19046969/Bitcoin-set-for-parabolic-rally-in-a-matter-of-weeks-as-halving-phase-begins', [1.7556625604629517, -0.9971216917037964, -1.9881765842437744]]
# ['2023-11-18 07:24:47+00:00', 'Numerous experts anticipate that the approval of Spot Bitcoin ETFs and the occurrence of Bitcoin halving will trigger a bullish … Continued', 'positive', 0.7886430025100708, 'https://cryptopanic.com/news/19046832/How-to-effectively-trade-the-upcoming-Solana-rally', [1.1428515911102295, -0.4645763039588928, -1.5513194799423218]]
# ['2023-11-17 23:00:59+00:00', 'Cardano may not be a top gainer in the crypto market but that does not mean that it has fallen behind. During the altcoin rally, the price of Cardano’s native coin ADA has gone from a low of $0.25 to a high of almost $0.4 before correcting back downwards. This positive trend has been preserved...', 'positive', 0.6750583052635193, 'https://cryptopanic.com/news/19046484/Cardano-Falling-Wedge-Pattern-Analyst-Predicts-100-Increase-Following-Breakout', [0.6042637228965759, -1.052565574645996, -0.6315068006515503]]
# ['2023-11-17 17:47:21+00:00', 'The Securities and Exchange Commission (SEC) has reportedly advised companies seeking to launch Bitcoin exchange-traded funds (ETFs) to amend their filings to switch to cash creations rather than in-kind creations, according to Bloomberg ETF analyst Eric Balchunas...', 'neutral', 0.8872327208518982, 'https://cryptopanic.com/news/19045928/SEC-Advises-Bitcoin-ETF-Firms-on-Cash-Creations-to-Address-Broker-Concerns', [-0.5047928690910339, -1.2274774312973022, 1.9537042379379272]]
# ['2023-11-17 17:13:05+00:00', 'BTC price experienced a sudden increase after the Bloomberg analyst stated that he heard about the Bitcoin Spot ETF. Continue Reading: BREAKING Bloomberg Analyst Says He Heard Insider Rumors About Bitcoin Spot ETF, Bitcoin Price Soars', 'positive', 0.9226166009902954, 'https://cryptopanic.com/news/19045874/BREAKING-Bloomberg-Analyst-Says-He-Heard-Insider-Rumors-About-Bitcoin-Spot-ETF-Bitcoin-Price-Soars', [1.722955584526062, -1.2430094480514526, -1.7077784538269043]]
# ['2023-11-17 14:38:43+00:00', 'Although Bitcoin (BTC) has started to slow down its gains from the past weeks that have seen it not just … Continued', 'negative', 0.9600017070770264, 'https://cryptopanic.com/news/19045396/Bitcoin-parabolic-bull-run-soon-as-BTC-hits-crucial-resistance-zone', [-1.3252875804901123, 2.6349050998687744, -1.1546630859375]]
# ['2023-11-17 11:22:11+00:00', 'Several cryptocurrencies, including Bitcoin (BTC) and Ethereum (ETH), have been systematically testing and pushing against new resistance levels amid the … Continued', 'positive', 0.7127140164375305, 'https://cryptopanic.com/news/19044918/3-cryptocurrencies-under-1-to-buy-next-week', [1.1971461772918701, -1.443740725517273, 0.09389141201972961]]
# ['2023-11-17 09:56:58+00:00', 'Numerous cryptocurrencies, such as Bitcoin (BTC) and Ethereum (ETH), have been methodically exploring and challenging new resistance levels during the … Continued', 'positive', 0.6807743906974792, 'https://cryptopanic.com/news/19044658/Dogecoin-on-chain-transactions-spike-Will-DOGE-hit-01', [1.063949465751648, -1.4071897268295288, 0.10794807970523834]]
# ['2023-11-16 21:18:11+00:00', '"If you look at Ethereum it was faster and cheaper than Bitcoin in the day. Solana is faster and more cost-effective than Ethereum," Wood pointed out.', 'positive', 0.8441488742828369, 'https://cryptopanic.com/news/19043758/Why-Cathie-Wood-Is-Bullish-on-Solana', [1.8131924867630005, -2.6459038257598877, 0.05903084576129913]]
# ['2023-11-16 12:30:00+00:00', 'One year ago today, El Salvador announced an ambitious plan to begin adding 1 Bitcoin per day to its national treasury.', 'positive', 0.7010449171066284, 'https://cryptopanic.com/news/19042398/Bitcoin-Price-Up-120-Since-El-Salvador-Became-First-Nation-to-Buy-1-BTC-A-Day', [1.505932092666626, -2.6779093742370605, 0.6172621846199036]]
# ['2023-11-16 11:27:27+00:00', 'Although many critics of the cryptocurrency sphere and Bitcoin (BTC), in particular, base their objections on their alleged negative impact … Continued', 'negative', 0.7630928754806519, 'https://cryptopanic.com/news/19042226/Bitcoin-uses-more-sustainable-energy-than-any-other-industry-data-shows', [-1.3646079301834106, 1.6971615552902222, 0.36403530836105347]]
# ['2023-11-15 13:15:29+00:00', 'While many cryptocurrencies like Bitcoin (BTC) and Ethereum (ETH) have been carefully testing new resistance levels throughout the current market … Continued', 'positive', 0.7182186245918274, 'https://cryptopanic.com/news/19039769/Solana-adds-4-billion-in-24-hours-Is-70-next-for-SOL', [1.340829610824585, -2.1130752563476562, 0.32115352153778076]]
# ['2023-11-15 10:25:03+00:00', 'Due to the soaring interest in artificial intelligence (AI) sparked by the launch of ChatGPT, similar platforms have demonstrated their … Continued', 'positive', 0.9210333824157715, 'https://cryptopanic.com/news/19039284/Google-Bard-predicts-Bitcoin-price-for-start-of-2024', [2.047532558441162, -2.4959447383880615, -0.5413931608200073]]
# ['2023-11-14 19:09:07+00:00', 'Chinese company Boyaa Interactive announced that it plans to invest $100 million, primarily in Bitcoin (BTC) and Ethereum (ETH). Continue Reading: Chinese Company Announces It Will Invest $100 Million in Bitcoin and Ethereum!', 'neutral', 0.6297678351402283, 'https://cryptopanic.com/news/19038018/Chinese-Company-Announces-It-Will-Invest-100-Million-in-Bitcoin-and-Ethereum', [0.8412174582481384, -2.50773024559021, 1.4069569110870361]]
# ['2023-11-14 18:14:06+00:00', 'Coinbase analysts said that if spot Bitcoin (BTC) ETFs are approved, new investor classes will come to the cryptocurrency market. Continue Reading: New Bitcoin Statement from Coinbase!', 'neutral', 0.8602360486984253, 'https://cryptopanic.com/news/19037925/New-Bitcoin-Statement-from-Coinbase', [0.22784514725208282, -2.403902053833008, 2.1145784854888916]]
# ['2023-11-14 14:31:47+00:00', 'According to the CEO of global investment management firm ARK Invest, Cathie Wood, the Bitcoin (BTC) and cryptocurrency sector could … Continued', 'negative', 0.8338466882705688, 'https://cryptopanic.com/news/19037326/67-billion-Ark-says-Bitcoin-and-crypto-to-be-worth-25-trillion-by-2030', [-1.1493501663208008, 1.8017927408218384, -0.11565792560577393]]
# ['2023-11-14 13:35:34+00:00', 'Crypto analyst Fiery Trading has an exceptionally bullish forecast for the price of Cardano (CRYPTO: ADA), suggesting a 9,990% surge to $35. read more', 'positive', 0.9387762546539307, 'https://cryptopanic.com/news/19037159/ADA-To-The-Moon-Analyst-Foresees-A-Whopping-10000-Surge-For-Cardano-Reaching-35-Levels', [1.8512853384017944, -1.5755654573440552, -1.5682536363601685]]
# ['2023-11-13 19:10:06+00:00', 'Amidst this anticipation, recent reports from esteemed data analytics platforms have set the crypto community abuzz, predicting a staggering $1 trillion market cap for crypto majors like Bitcoin, XRP, Ether, Solana, Cardano, and Shiba Inu if spot ETFs receive the green light.', 'positive', 0.4963992238044739, 'https://cryptopanic.com/news/19035412/XRP-Ether-Solana-Cardano-Shiba-Inu-Brace-For-1-Trillion-Bull-Shock-As-Spot-Bitcoin-ETF-Comes-Nigh', [0.5527161955833435, 0.4725256562232971, -1.837967872619629]]
# ['2023-11-13 11:40:32+00:00', 'For months, the crypto markets, spearheaded by Bitcoin (BTC), languished in a constrained and subdued trading range, lacking significant catalysts. … Continued', 'negative', 0.9183249473571777, 'https://cryptopanic.com/news/19034267/Crypto-eyeing-historic-move-as-tons-of-new-liquidity-return-to-market', [-1.8279696702957153, 2.5714454650878906, 0.0030013162177056074]]
# ['2023-11-13 10:43:41+00:00', 'While Bitcoin (BTC) and Ethereum (ETH) are guaranteed to take the spotlight in any crypto market rally, Solana (SOL) has … Continued', 'positive', 0.9060449600219727, 'https://cryptopanic.com/news/19034107/Coinbase-to-launch-Solana-perpetual-futures-Will-the-SOL-rally-continue', [1.8470523357391357, -2.217559337615967, -0.6002312898635864]]
# ['2023-11-13 09:44:26+00:00', 'In his latest jab at traditional financial institutions, renowned investor and author of the best-selling finance book ‘Rich Dad Poor … Continued', 'neutral', 0.6585532426834106, 'https://cryptopanic.com/news/19033973/Rich-Dad-R-Kiyosaki-Protect-yourself-from-Central-Bankers-by-saving-Bitcoin', [-0.09140850603580475, -0.1755480021238327, 1.217407464981079]]
# ['2023-11-13 07:10:29+00:00', 'Nate Geraci, President of the ETF Store and host of the ETF Prime podcast, has brought to light a critical juncture in the potential approval of spot Bitcoin Exchange-Traded Funds (ETFs) by the US Securities and Exchange Commission (SEC). Citing Bloomberg analyst James Seyffart, Geraci’s post on...', 'neutral', 0.5254794359207153, 'https://cryptopanic.com/news/19033704/Spot-Bitcoin-ETF-Approval-Could-Come-This-Week-Expert', [1.1728485822677612, -2.7339911460876465, 1.2947591543197632]]
# ['2023-11-12 18:05:00+00:00', "Grayscale's Solana Trust sees explosive growth as institutional investors seek exposure to Solana.", 'positive', 0.9222538471221924, 'https://cryptopanic.com/news/19033148/Could-a-Solana-ETF-Be-Next-as-GSOL-Reaches-All-Time-High', [1.7239121198654175, -1.7135499715805054, -1.2296442985534668]]
# ['2023-11-12 16:56:08+00:00', 'The Solana ecosystem is experiencing a robust uptrend, overcoming the challenges of the bear market. The substantial appreciation of the price of SOL and a distinct shift in market sentiment marks a noteworthy resurgence. Data from BeInCrypto shows that Solana’s SOL briefly touched the $60 mark...', 'positive', 0.955413818359375, 'https://cryptopanic.com/news/19033118/Solana-Eclipses-60-A-Detailed-Look-at-the-Factors-Driving-SOL-Price-Rally', [2.072099447250366, -1.7652337551116943, -1.6121565103530884]]
# ['2023-11-12 14:15:12+00:00', 'Bitcoin (BTC) continues to trade in the green zone as the maiden cryptocurrency endeavors to surge toward a new all-time … Continued', 'positive', 0.9350541234016418, 'https://cryptopanic.com/news/19032920/Over-60000-Bitcoin-millionaires-emerge-in-2023-3x-more-since-January', [1.9949344396591187, -2.1230814456939697, -0.9391396641731262]]
# ['2023-11-12 09:18:34+00:00', 'Aside from SOL, the other notable gainers today include AVAX, RUNE, LINK, DOT, and more.', 'neutral', 0.8528599739074707, 'https://cryptopanic.com/news/19032640/Solana-SOL-Explodes-45-Weekly-Bitcoin-BTC-Maintains-37K-Weekend-Watch', [0.3071276545524597, -2.3707077503204346, 2.1307921409606934]]
# ['2023-11-12 08:52:40+00:00', 'The current cryptocurrency market is witnessing a substantial surge, capturing the attention of investors. While cryptocurrencies like Bitcoin and Ethereum … Continued', 'positive', 0.9310742020606995, 'https://cryptopanic.com/news/19032624/Top-3-cryptocurrencies-under-010-to-buy-next-week', [1.8928872346878052, -2.2270405292510986, -0.9581815004348755]]
# ['2023-11-12 07:00:59+00:00', 'Saylor forecasts a 10x Bitcoin boom by 2024, with big tech and banks struggling for a piece.', 'negative', 0.5012079477310181, 'https://cryptopanic.com/news/19032545/Bitcoin-Demand-Will-Boom-in-2024-Micheal-Saylor-Predicts', [-0.5761292576789856, 0.4817684590816498, 0.04789623245596886]]
# ['2023-11-11 16:29:34+00:00', 'A short bull run marked the last 30 days in the cryptocurrency market, with Bitcoin (BTC) leading the way for … Continued', 'positive', 0.5402381420135498, 'https://cryptopanic.com/news/19032010/365-billion-inflows-crypto-market-cap-in-a-month-but-whats-next', [0.6869977712631226, -0.6015906929969788, 0.1342664510011673]]
# ['2023-11-11 12:24:06+00:00', 'Bitcoin (BTC) has surged above $37,000, reaching its highest price in 18 months, driven by growing optimism that regulators may … Continued', 'positive', 0.9434053897857666, 'https://cryptopanic.com/news/19031697/Biggest-bull-run-ever-looms-for-Bitcoin-as-this-indicator-reappears-after-8-years', [1.9490281343460083, -1.632155179977417, -1.4884095191955566]]
# ['2023-11-10 09:30:58+00:00', 'Amid warnings of an unfolding widespread financial crisis, Robert Kiyosaki, a renowned investor and author of the best-selling personal finance … Continued', 'neutral', 0.4620308578014374, 'https://cryptopanic.com/news/19029202/Rich-Dad-R-Kiyosaki-Save-gold-silver-Bitcoin-as-leaders-want-war', [-0.34125879406929016, 0.23205560445785522, 0.5269113183021545]]
# ['2023-11-09 15:48:51+00:00', 'Bitcoin surges past $37K, a first since the Terra fallout, with ETF approval hopes rising.', 'positive', 0.9433394074440002, 'https://cryptopanic.com/news/19027489/Bitcoin-Surges-Past-37000-Find-Out-Why', [1.9530856609344482, -1.6922987699508667, -1.429706335067749]]
# ['2023-11-09 15:38:14+00:00', 'BlackRock has taken the initial step toward filing for a spot Ether ETF, with the iShares Ethereum Trust recently registered in Delaware. This move is reminiscent of BlackRock’s iShares Bitcoin Trust, which was registered in a similar fashion seven days before the ETF application was filed with...', 'neutral', 0.5683257579803467, 'https://cryptopanic.com/news/19027434/ETH-crosses-2k-as-BlackRocks-Ethereum-Trust-ETF-filing-surfaces', [0.9728084802627563, -2.534867763519287, 1.2773581743240356]]
# ['2023-11-09 15:23:32+00:00', 'A previous period of gains in the cryptocurrency world saw Bitcoin (BTC) rise in value, which hasn’t gone unnoticed by … Continued', 'positive', 0.9505947232246399, 'https://cryptopanic.com/news/19027407/Robinhood-to-launch-Bitcoin-and-crypto-trading-in-the-EU-and-UK', [2.024773359298706, -1.9241933822631836, -1.3956563472747803]]
# ...
# ['2023-10-30 12:35:26+00:00', 'A fresh wave of investor optimism has breathed new life into the crypto markets over the past week, driving Bitcoin … Continued', 'positive', 0.9019041657447815, 'https://cryptopanic.com/news/19003421/Can-DOGE-reach-01-as-it-breaks-out-of-multi-year-bearish-pattern', [1.725719690322876, -1.8764328956604004, -0.7814294695854187]]
# ['2023-10-30 12:28:07+00:00', 'Cryptocurrency exchange Binance announced to its users that this altcoin supports the mainnet transition. Continue Reading: Bitcoin Exchange Binance Announced That It Supports the Mainnet of This Altcoin!', 'neutral', 0.7958636283874512, 'https://cryptopanic.com/news/19003405/Bitcoin-Exchange-Binance-Announced-That-It-Supports-the-Mainnet-of-This-Altcoin', [0.4079819321632385, -2.4494800567626953, 1.8244479894638062]]
# ['2023-10-30 09:43:11+00:00', 'After languishing below the $30,000 mark for nearly three months, Bitcoin (BTC) has finally broken free, surging past $34,000 in … Continued', 'positive', 0.9119065999984741, 'https://cryptopanic.com/news/19003008/Bitcoin-to-hit-50000-pre-halving-says-crypto-expert', [1.692824125289917, -1.429843544960022, -1.2528988122940063]]
# ['2023-10-30 07:04:59+00:00', 'A trader who continues to build a following with his timely Bitcoin (BTC) calls as of late thinks that the crypto king is gearing up for a parabolic surge. Pseudonymous analyst Credible Crypto tells his 349,100 followers on the social media platform X that BTC appears to have printed a local...', 'neutral', 0.7815285921096802, 'https://cryptopanic.com/news/19002706/Bitcoin-BTC-Just-About-Ready-for-Parabolic-Leg-Up-According-to-Crypto-Strategist-Here-Are-His-Targets', [-0.6811970472335815, -0.3682134747505188, 1.4552335739135742]]
# ['2023-10-29 18:52:31+00:00', 'El Salvador is being hailed as a potential financial hub in the Americas, drawing comparisons to Singapore, according to Gabor Gurbacs, a strategy adviser at VanEck, an investment management firm. Gurbacs expressed this sentiment in a recent post on X (formerly Twitter), suggesting that El...', 'positive', 0.8742658495903015, 'https://cryptopanic.com/news/19002193/El-Salvador-tipped-to-become-a-financial-powerhouse-in-the-Americas', [1.8584983348846436, -2.438969135284424, -0.18007853627204895]]
# ['2023-10-29 13:02:45+00:00', 'In a time of global economic uncertainty, managing investment portfolios has become a critical topic among investors seeking ways to … Continued', 'neutral', 0.879393458366394, 'https://cryptopanic.com/news/19001837/Rich-Dad-R-Kiyosaki-shares-mix-to-survive-the-greatest-crash-in-world-history', [-0.03892110288143158, -1.666926383972168, 2.127028703689575]]
# ['2023-10-29 03:26:59+00:00', 'VanEck strategy adviser Gabor Gurbacs expects a wave of new investment capital and immigration will push El Salvador’s economic growth in the coming years.', 'positive', 0.9397398233413696, 'https://cryptopanic.com/news/19001437/Bitcoin-friendly-El-Salvador-can-become-Singapore-of-the-Americas-VanEck-adviser', [1.990970253944397, -2.20530104637146, -1.023482322692871]]
# ['2023-10-28 16:00:51+00:00', 'A Bitcoin adopter has outlined the various achievements of XRP, foreseeing a significant price increase for the cryptocurrency that could move it closer to the $10 milestone. Bitcoin OG Says XRP $10 In Sight In an X (formerly Twitter) post, Bitcoin OG, Lucky predicted that the value of XRP could...', 'positive', 0.9266077876091003, 'https://cryptopanic.com/news/19001025/Early-Bitcoin-Adopter-Says-XRP-Price-Is-Closer-To-10-Than-You-Think-Heres-Why', [2.0165159702301025, -2.4755184650421143, -0.6716212034225464]]
# ['2023-10-28 11:13:36+00:00', 'The recent Bitcoin (BTC) resurgence is driving increased interest in the possibility of the crypto hitting a new all-time high, … Continued', 'positive', 0.9430937767028809, 'https://cryptopanic.com/news/19000677/This-is-when-Bitcoin-might-hit-the-highly-anticipated-100k-mark', [1.9769014120101929, -1.9394429922103882, -1.2313768863677979]]
# ['2023-10-28 09:22:05+00:00', 'The cryptocurrency market remains a focal point of attention due to speculation about the potential approval of a spot Bitcoin … Continued', 'neutral', 0.5364317297935486, 'https://cryptopanic.com/news/19000526/Former-SEC-insider-says-spot-Bitcoin-ETF-is-a-matter-of-months', [0.39427661895751953, -1.234999656677246, 0.7193045616149902]]
# ['2023-10-28 08:32:59+00:00', 'The cryptocurrency market is a realm teeming with opportunities. Although the limelight frequently falls on prominent cryptocurrencies such as Bitcoin … Continued', 'neutral', 0.6516344547271729, 'https://cryptopanic.com/news/19000458/3-cryptocurrencies-to-buy-under-1-next-week', [0.6447819471359253, -1.9319589138031006, 1.3442838191986084]]
# ['2023-10-27 00:59:00+00:00', 'Google searches relating to purchasing Bitcoin have spiked worldwide following a significant rally in the price of BTC.', 'positive', 0.9363215565681458, 'https://cryptopanic.com/news/18997593/Buy-Bitcoin-search-queries-on-Google-surge-826-in-the-UK', [1.899239182472229, -1.3261181116104126, -1.66680109500885]]
# ['2023-10-26 16:30:20+00:00', 'Mexican Senator Indira Kempis made waves last year when she introduced legislation to create a central bank digital currency (CBDC). Now, she’s shifting her focus to make Bitcoin a central part of her political agenda. Kempis, a congresswoman from the state of Nuevo León in Mexico, initially had...', 'neutral', 0.7539997696876526, 'https://cryptopanic.com/news/18996725/Mexican-Senator-pushes-bill-to-make-Bitcoin-a-legal-tender', [0.41099369525909424, -2.1518702507019043, 1.6053104400634766]]
# ['2023-10-26 13:03:37+00:00', 'As the artificial intelligence (AI) hype, triggered by the launch of the OpenAI brainchild ChatGPT, still remains strong, the technology … Continued', 'positive', 0.7656853795051575, 'https://cryptopanic.com/news/18996171/ChatGPT-picks-5-cryptocurrencies-to-buy-for-Halloween', [1.5637239217758179, -2.156749725341797, 0.2971552908420563]]
# ['2023-10-26 12:57:00+00:00', 'The cryptocurrency analyst and investor CryptoKaleo shared on X earlier today that the Avalanche (AVAX) and Bitcoin (BTC) trading pair could start making a move upwards soon. According to the post, the pair is starting to bounce off of a bottom on the 4-hour chart. The AVAX/BTC pair rebounded...', 'positive', 0.9103106260299683, 'https://cryptopanic.com/news/18996155/Avalanche-AVAX-Is-Primed-To-Catch-Up-to-BTC-Predicts-Analyst', [1.6233491897583008, -1.3200371265411377, -1.4592702388763428]]
# ['2023-10-26 12:24:59+00:00', 'Bitcoin (BTC), the largest cryptocurrency globally, has once again captured the interest of the financial world due to its recent … Continued', 'positive', 0.9344240427017212, 'https://cryptopanic.com/news/18996013/Bitcoin-flips-Teslas-market-capitalization-amid-strong-BTC-price-rally', [2.0395545959472656, -2.3556015491485596, -0.8105030655860901]]
# ['2023-10-25 18:01:06+00:00', 'It was revealed that SEC officials had an important meeting with Hashdex, the company that applied for Bitcoin Spot ETF. Continue Reading: SEC Met with One of the Applicants Regarding the Bitcoin Spot ETF: Here are the Details of the Meeting', 'neutral', 0.9480722546577454, 'https://cryptopanic.com/news/18994210/SEC-Met-with-One-of-the-Applicants-Regarding-the-Bitcoin-Spot-ETF-Here-are-the-Details-of-the-Meeting', [-0.9699751138687134, -1.1053825616836548, 2.562335968017578]]
# ['2023-10-25 16:30:44+00:00', "Shiba Inu surged by 6% in the past 24 hours, riding the wave of Bitcoin's rise to $35,000, fueled by market excitement over the possible...", 'positive', 0.9483708143234253, 'https://cryptopanic.com/news/18994014/0001-SHIB-Price-In-View-As-Shiba-Inu-Sees-Explosive-Volume-Amid-Bitcoins-Charge-To-35000', [1.9804844856262207, -1.751502275466919, -1.5097191333770752]]
# ['2023-10-25 09:40:19+00:00', 'Cardano has taken center stage on an exciting day in the cryptocurrency market, marked by Bitcoin’s brief flirtation with the $35,000 level. The eighth-largest digital asset by market capitalization, ADA, is once again sparking optimism among investors as it edges closer to the coveted $1 price...', 'positive', 0.9256402254104614, 'https://cryptopanic.com/news/18992708/Cardano-Path-To-1-How-Staking-Updates-Could-Ignite-A-Rally', [1.9177727699279785, -2.349217653274536, -0.795650839805603]]
# ['2023-10-24 22:10:06+00:00', "After BlackRock's Bitcoin Spot ETF was listed on the DTCC list with the code IBTC yesterday, it was thought that it was only a matter of time before the BTC Spot ETF would receive approval from the SEC. However, this listing was removed today evening. BTC, which experienced a decline after the...", 'negative', 0.8880017399787903, 'https://cryptopanic.com/news/18991775/JUST-IN-Blackrock-Spot-Bitcoin-ETF-Relisted-on-DTCC-Bitcoin-is-Moving', [-1.2697839736938477, 1.88491952419281, -0.5983151793479919]]
# ['2023-10-24 17:30:00+00:00', 'Cardano poised to ride institutional adoption wave', 'positive', 0.7699384093284607, 'https://cryptopanic.com/news/18991268/ADA-BTC-to-Gain-Institutional-Exposure-as-Grayscale-Unveils-Crypto-Indices', [1.807396411895752, -2.8683888912200928, 0.5677517652511597]]
# ['2023-10-24 16:07:02+00:00', "BlackRock's highly anticipated spot bitcoin ETF, the iShares Bitcoin Trust, no longer appeared on a list maintained by the DTCC.", 'neutral', 0.7949560880661011, 'https://cryptopanic.com/news/18991025/BlackRocks-bitcoin-ETF-disappears-from-DTCC-list-in-latest-update', [-1.7197527885437012, 0.5996769070625305, 2.048530101776123]]
# ['2023-10-24 14:01:48+00:00', 'Amid an enthusiastic day on the cryptocurrency market that began with Bitcoin (BTC) briefly tapping the $35,000 level, Cardano (ADA) … Continued', 'positive', 0.9131167531013489, 'https://cryptopanic.com/news/18990658/Could-Cardano-reach-1-ADA-climbs-10', [1.8483200073242188, -2.010019063949585, -0.754733145236969]]
# ['2023-10-24 09:49:56+00:00', 'Following a massive upside push that the cryptocurrency market has recently made under the leadership of Bitcoin (BTC), artificial intelligence … Continued', 'positive', 0.6880172491073608, 'https://cryptopanic.com/news/18989939/AI-predicts-Bitcoin-price-for-Halloween-2023', [1.3714163303375244, -2.0108070373535156, 0.5026770830154419]]
# ['2023-10-24 08:29:19+00:00', 'As Bitcoin (BTC) remained above the critical psychological level at $30,000 and then moved further up, breaking its yearly high … Continued', 'positive', 0.9115844368934631, 'https://cryptopanic.com/news/18989753/Bitcoin-party-has-not-even-started-as-BTC-eyes-40k', [1.7096796035766602, -1.1335595846176147, -1.5408337116241455]]
# ['2023-10-23 22:14:25+00:00', 'Bitcoin price just set a higher high above the current 2023 high and 52-week high. What’s next after this as Bitcoin bulls continue to march upward? Bitcoin Price Sets New 52-Week High Bitcoin price is now trading above $31,800, which was the most recent 2023 high set back in July. Not only did...', 'positive', 0.7504128217697144, 'https://cryptopanic.com/news/18989072/BREAKING-Bitcoin-Price-Sets-New-2023-Record-52-Week-High', [1.2416149377822876, -2.060054302215576, 0.023469800129532814]]
# ['2023-10-23 21:54:40+00:00', "BlackRock's proposed spot bitcoin ETF turned up on list maintained by the DTCC with the ticker IBTC. It's still pending review by the SEC.", 'neutral', 0.8390687108039856, 'https://cryptopanic.com/news/18989054/BlackRocks-spot-bitcoin-ETF-appears-on-DTCC-website-with-ticker-IBTC', [-1.5247682332992554, 0.27473780512809753, 2.0791006088256836]]
# ['2023-10-23 20:01:05+00:00', "BlackRock's latest move indicates that a Bitcoin spot ETF could be imminent, according to a Bloomberg analyst. Continue Reading: Bitcoin Spot ETF One Step Closer: BlackRock Makes New Move, Could Be Just Around the Corner", 'positive', 0.6096662878990173, 'https://cryptopanic.com/news/18988818/Bitcoin-Spot-ETF-One-Step-Closer-BlackRock-Makes-New-Move-Could-Be-Just-Around-the-Corner', [1.0241775512695312, -2.2262516021728516, 0.5158222913742065]]
# ['2023-10-23 18:53:04+00:00', "According to breaking information, in the Grayscale case, the court allowed the company to proceed with its Bitcoin Spot ETF application and send the application back to the SEC. The court provided instructions to the SEC on how to proceed with Grayscale's Bitcoin Spot ETF application. GBTC...", 'neutral', 0.934744656085968, 'https://cryptopanic.com/news/18988705/BREAKING-Grayscale-Gets-Court-Approval-to-Proceed-with-Bitcoin-Spot-ETF-Application', [-0.49604904651641846, -1.7173880338668823, 2.4243004322052]]
# ['2023-10-23 14:28:51+00:00', 'On October 23, 2023, Bitcoin (BTC) made another headlining move. With its value currently pegged at $30,582, Bitcoin has experienced … Continued', 'positive', 0.9097468852996826, 'https://cryptopanic.com/news/18988057/Bitcoin-rockets-toward-72-week-high', [1.8188223838806152, -2.1144111156463623, -0.7115857601165771]]
# ['2023-10-23 10:53:30+00:00', 'As the bullish wave on the wider crypto market continues, partially triggered by the court victory of blockchain company Ripple … Continued', 'negative', 0.5080642700195312, 'https://cryptopanic.com/news/18987475/How-much-will-1-Bitcoin-be-worth-in-2030', [0.1718127727508545, 0.4135228097438812, -1.2849042415618896]]
# ['2023-10-23 09:44:31+00:00', 'As the week has opened with bullish sentiment on the general cryptocurrency market, its representative asset, Bitcoin (BTC), has finally … Continued', 'positive', 0.9271408319473267, 'https://cryptopanic.com/news/18987292/Rich-Dad-R-Kiyosaki-Next-stop-for-Bitcoin-135000', [1.8280284404754639, -1.4746477603912354, -1.3468258380889893]]
# ['2023-10-23 09:26:53+00:00', 'Bitcoin (BTC) surged to a three-month high during the first trading session in Asia on October 23, igniting hopes of … Continued', 'positive', 0.9286993741989136, 'https://cryptopanic.com/news/18987237/Bitcoin-chart-hints-at-major-sell-signal-warns-analyst', [1.8180080652236938, -1.7444777488708496, -1.210113286972046]]
# ['2023-10-23 05:39:30+00:00', 'No verified real-world attacks have been linked to “replacement cycling attacks" on Lightning network in the past 10 months.', 'neutral', 0.6327772736549377, 'https://cryptopanic.com/news/18986814/Developer-exposed-potential-security-issue-on-the-Lightning-Network', [-1.4701874256134033, 0.9442382454872131, 1.5740324258804321]]
# ['2023-10-22 23:15:00+00:00', 'With the SEC losing its grip, market participants are growing excited about a potential spot ETF approval.', 'positive', 0.9114206433296204, 'https://cryptopanic.com/news/18986570/Coinbase-Chief-Legal-Officer-Expects-Bitcoin-ETF-Approvals-Soon', [1.6014068126678467, -1.495213508605957, -1.3553634881973267]]
# ['2023-10-22 19:03:58+00:00', 'The Bitcoin use in Silk Road opened up the crypto industry to regulatory fights that tie digital assets with illegal activities such as funding wars, terrorism, and drug trade. The crypto market is full of risks, and among them are cybercrimes and fraud cases. Since their inception, the digital...', 'neutral', 0.8109133243560791, 'https://cryptopanic.com/news/18986422/Police-finally-apprehend-50000-Bitcoin-Silk-Road-thief', [-1.1093496084213257, 0.035014163702726364, 1.7674084901809692]]
# ['2023-10-22 11:50:16+00:00', 'The cryptocurrency market, with Bitcoin (BTC) at the forefront, has attracted significant attention from both investors and analysts after a … Continued', 'positive', 0.9426988959312439, 'https://cryptopanic.com/news/18985986/Can-BTC-reach-45k-by-the-end-of-2023', [2.0079758167266846, -2.1381614208221436, -1.0940356254577637]]
# ['2023-10-22 10:33:41+00:00', 'Lawrence White, a prominent professor of economics at George Mason University, has highlighted a potential future security threat that faces … Continued', 'neutral', 0.5082196593284607, 'https://cryptopanic.com/news/18985919/Economics-professor-identifies-future-security-threat-to-Bitcoin', [-0.5047237277030945, 0.4239453673362732, 0.7897781729698181]]

# %%
import csv
import datetime

# Get today's date in YYYYMMDD format
todays_date = datetime.datetime.now().strftime('%Y%m%d')

# Define the new CSV file path with today's date
new_csv_file_path = 'exports_by_date/assetsummaries_crypto_panic_bert_{}.csv'.format(todays_date)

# Save the final_output to the CSV file with the new name
with open(new_csv_file_path, mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerows(final_output)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[9], line 13
#      11 with open(new_csv_file_path, mode='w', newline='') as f:
#      12     csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
# ---> 13     csv_writer.writerows(final_output)
#
# File D:\Apps\anaconda3\envs\djwood\lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2713' in position 110: character maps to <undefined>

# %%
import csv
import datetime

# Get today's date in YYYYMMDD format
todays_date = datetime.datetime.now().strftime('%Y%m%d')

# Define the new CSV file path with today's date
new_csv_file_path = 'exports_by_date/assetsummaries_crypto_panic_bert_{}.csv'.format(todays_date)

# Save the final_output to the CSV file with the new name
with open(new_csv_file_path, mode='w', newline='', encoding='utf-8') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerows(final_output)

# %%
import os
import pandas as pd

# Define the directory where the CSV files are located
directory = r'D:\Documents\GitHub\cryptopanic_API_Wrapper\exports_by_date'

# Define the output file name
output_filename = 'assetsummaries_crypto_panic_bert_all.csv'

# Combine the directory and output filename to create the full output path
output_path = os.path.join(directory, output_filename)

# Check if the output file exists and delete it if it does
if os.path.exists(output_path):
    os.remove(output_path)
    print(f'{output_filename} already exists and has been deleted.')

# Initialize an empty list to store DataFrames
dfs = []

# Loop through the files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        file_path = os.path.join(directory, filename)
        try:
            # Read each CSV file into a DataFrame with 'ISO-8859-1' encoding
            df = pd.read_csv(file_path, encoding='ISO-8859-1')
            
            # Drop the "Logits" columns if they exist
            if "Logits" in df.columns:
                df = df.drop(columns=["Logits"])
            
            # Append the DataFrame to the list
            dfs.append(df)
        except UnicodeDecodeError:
            print(f"UnicodeDecodeError occurred while reading {file_path}. Skipping this file.")

# Concatenate the list of DataFrames into a single DataFrame
combined_df = pd.concat(dfs, ignore_index=True)

# Sort the combined DataFrame in descending order by date
combined_df['Date'] = pd.to_datetime(combined_df['Date'])
combined_df = combined_df.sort_values(by='Date', ascending=False)

# Drop all duplicate rows
combined_df.drop_duplicates(subset=['Date'], keep='first', inplace=True)

# Save the combined and deduplicated DataFrame to a new CSV file
combined_df.to_csv(output_path, index=False)

# Print a message to indicate the process is complete
print(f'Data has been combined, "Logits" columns dropped, sorted in descending order by date, all duplicates removed, and saved to {output_path}.')
