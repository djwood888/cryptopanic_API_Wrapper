# %%
"""
CryptoPanic API Wrapper.

Docs for API found here. https://cryptopanic.com/developers/api/

CryptoPanic Server is cached every 30 seconds. So crawling at a faster rate is pointless.
All API methods are rate limited per IP at 5req/sec.

Use like this:

    df = concatenate_pages(pages_list=get_pages_list_json(2, make_url(filter='hot', currencies='btc,eth,xrp')))

"""

import requests
import pandas as pd
import datetime
import config
import time

# main_script.py
import config

# Access the API key
api_key = config.API_KEY


global_api_rate_delay = .2  # All API methods are rate limited per IP at 5req/sec.


def make_url(filter=None, currencies=None, kind=None, region=None, page=None):
    """Handle of URL variables for API POST."""
    url = 'https://cryptopanic.com/api/v1/posts/?auth_token={}'.format(config.API_KEY)

    if currencies is not None:
        if len(currencies.split(',')) <= 50:
            url += "&currencies={}".format(currencies)
        else:
            print("Warning: Max Currencies is 50")
            return

    if kind is not None and kind in ['news', 'media']:
        url += "&kind={}".format(kind)

    filters = ['rising', 'hot', 'bullish', 'bearish', 'important', 'saved', 'lol']
    if filter is not None and filter in filters:
        url += "&filter={}".format(filter)

    regions = ['en', 'de', 'es', 'fr', 'it', 'pt', 'ru']  # (English), (Deutsch), (Español), (Français), (Italiano), (Português), (Русский)--> Respectively
    if region is not None and region in regions:
        url += "&region={}".format(region)

    if page is not None:
        url += "&page={}".format(page)

    return url


def get_page_json(url=None):
    """
    Get First Page.

    Returns Json.

    """
    time.sleep(global_api_rate_delay)
    if not url:
        url = "https://cryptopanic.com/api/v1/posts/?auth_token={}".format(config.API_KEY)
    page = requests.get(url)
    data = page.json()
    return data


def get_pages_list_json(lookback, url):
    """
    Get history of pages starting from page 1 to the lookback.

    Returns: List of Pages in Json format

    """
    pages_list_json = [get_page_json(url)]

    for i in range(lookback):
        pages_list_json.append(get_page_json(pages_list_json[i]["next"]))

    return pages_list_json


def get_df(data):
    """Return pandas DF."""
    df = pd.DataFrame(data)
    try:
        df['created_at'] = pd.to_datetime(df.created_at)
    except Exception as e:
        pass

    return df


def concatenate_pages(pages_list):
    """Concatenate Pages into one Dataframe."""
    frames = []
    for page in pages_list:
        frames.append(get_df(page))

    return pd.concat(frames, ignore_index=True)

# df = concatenate_pages(get_pages_list_json(2, make_url()))

df = concatenate_pages(pages_list=get_pages_list_json(2, make_url(filter='hot', currencies='btc')))
df
# Out:
#     count                                               next  \
# 0     200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 1     200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 2     200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 3     200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 4     200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 5     200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 6     200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 7     200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 8     200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 9     200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 10    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 11    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 12    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 13    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 14    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 15    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 16    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 17    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 18    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 19    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 20    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 21    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 22    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 23    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 24    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 25    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 26    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 27    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 28    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 29    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 30    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 31    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 32    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 33    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 34    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 35    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 36    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 37    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 38    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 39    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 40    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 41    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 42    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 43    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 44    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 45    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 46    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 47    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 48    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 49    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 50    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 51    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 52    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 53    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 54    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 55    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 56    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 57    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 58    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 59    200  https://cryptopanic.com/api/v1/posts/?auth_tok...
#
#                                              previous  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 21  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 22  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 23  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 24  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 25  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 26  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 27  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 28  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 29  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 30  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 31  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 32  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 33  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 34  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 35  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 36  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 37  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 38  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 39  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 40  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 41  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 42  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 43  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 44  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 45  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 46  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 47  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 48  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 49  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 50  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 51  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 52  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 53  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 54  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 55  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 56  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 57  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 58  https://cryptopanic.com/api/v1/posts/?auth_tok...
# 59  https://cryptopanic.com/api/v1/posts/?auth_tok...
#
#                                               results
# 0   {'kind': 'news', 'domain': 'en.bitcoinsistemi....
# 1   {'kind': 'news', 'domain': 'newsbtc.com', 'vot...
# 2   {'kind': 'news', 'domain': 'newsbtc.com', 'vot...
# 3   {'kind': 'news', 'domain': 'cryptobriefing.com...
# 4   {'kind': 'news', 'domain': 'en.bitcoinsistemi....
# 5   {'kind': 'news', 'domain': 'decrypt.co', 'vote...
# 6   {'kind': 'news', 'domain': 'finbold.com', 'vot...
# 7   {'kind': 'news', 'domain': 'coinpaprika.com', ...
# 8   {'kind': 'news', 'domain': 'en.bitcoinsistemi....
# 9   {'kind': 'news', 'domain': 'feeds2.benzinga.co...
# 10  {'kind': 'news', 'domain': 'coinpaprika.com', ...
# 11  {'kind': 'news', 'domain': 'newsbtc.com', 'vot...
# 12  {'kind': 'news', 'domain': 'finbold.com', 'vot...
# 13  {'kind': 'news', 'domain': 'bitcoinist.com', '...
# 14  {'kind': 'news', 'domain': 'dailycoin.com', 'v...
# 15  {'kind': 'news', 'domain': 'cryptopotato.com',...
# 16  {'kind': 'news', 'domain': 'coinpaprika.com', ...
# 17  {'kind': 'news', 'domain': 'finbold.com', 'vot...
# 18  {'kind': 'news', 'domain': 'finbold.com', 'vot...
# 19  {'kind': 'news', 'domain': 'cryptoslate.com', ...
# 20  {'kind': 'news', 'domain': 'en.bitcoinsistemi....
# 21  {'kind': 'news', 'domain': 'coinpaprika.com', ...
# 22  {'kind': 'news', 'domain': 'coinpaprika.com', ...
# 23  {'kind': 'news', 'domain': 'decrypt.co', 'vote...
# 24  {'kind': 'news', 'domain': 'theblock.co', 'vot...
# 25  {'kind': 'news', 'domain': 'newsbtc.com', 'vot...
# 26  {'kind': 'news', 'domain': 'coindesk.com', 'vo...
# 27  {'kind': 'news', 'domain': 'coindesk.com', 'vo...
# 28  {'kind': 'news', 'domain': 'cryptopotato.com',...
# 29  {'kind': 'news', 'domain': 'coinpaprika.com', ...
# 30  {'kind': 'news', 'domain': 'coinpaprika.com', ...
# 31  {'kind': 'news', 'domain': 'cointelegraph.com'...
# 32  {'kind': 'news', 'domain': 'trustnodes.com', '...
# 33  {'kind': 'news', 'domain': 'en.bitcoinsistemi....
# 34  {'kind': 'news', 'domain': 'coinpaprika.com', ...
# 35  {'kind': 'news', 'domain': 'coinpaprika.com', ...
# 36  {'kind': 'news', 'domain': 'finbold.com', 'vot...
# 37  {'kind': 'news', 'domain': 'newsbtc.com', 'vot...
# 38  {'kind': 'news', 'domain': 'zycrypto.com', 'vo...
# 39  {'kind': 'news', 'domain': 'newsbtc.com', 'vot...
# 40  {'kind': 'news', 'domain': 'finbold.com', 'vot...
# 41  {'kind': 'news', 'domain': 'newsbtc.com', 'vot...
# 42  {'kind': 'news', 'domain': 'zycrypto.com', 'vo...
# 43  {'kind': 'news', 'domain': 'cointelegraph.com'...
# 44  {'kind': 'news', 'domain': 'en.bitcoinsistemi....
# 45  {'kind': 'news', 'domain': 'theblock.co', 'vot...
# 46  {'kind': 'news', 'domain': 'finbold.com', 'vot...
# 47  {'kind': 'news', 'domain': 'zycrypto.com', 'vo...
# 48  {'kind': 'news', 'domain': 'dailyhodl.com', 'v...
# 49  {'kind': 'news', 'domain': 'cryptopolitan.com'...
# 50  {'kind': 'news', 'domain': 'cointelegraph.com'...
# 51  {'kind': 'news', 'domain': 'bitcoinist.com', '...
# 52  {'kind': 'news', 'domain': 'cointelegraph.com'...
# 53  {'kind': 'news', 'domain': 'cryptopolitan.com'...
# 54  {'kind': 'news', 'domain': 'finbold.com', 'vot...
# 55  {'kind': 'news', 'domain': 'coinedition.com', ...
# 56  {'kind': 'news', 'domain': 'en.bitcoinsistemi....
# 57  {'kind': 'news', 'domain': 'zycrypto.com', 'vo...
# 58  {'kind': 'news', 'domain': 'bitcoinist.com', '...
# 59  {'kind': 'news', 'domain': 'en.bitcoinsistemi....

# %%
import requests
import pandas as pd
import datetime
import config
import time

# main_script.py
import config

# Access the API key
api_key = config.API_KEY

def make_url(filter=None, currencies=None, kind=None, region=None, page=None):
    """Handle of URL variables for API POST."""
    url = 'https://cryptopanic.com/api/v1/posts/?auth_token={}'.format(config.API_KEY)

    if currencies is not None:
        if len(currencies.split(',')) <= 50:
            url += "&currencies={}".format(currencies)
        else:
            print("Warning: Max Currencies is 50")
            return

    if kind is not None and kind in ['news', 'media']:
        url += "&kind={}".format(kind)

    filters = ['rising', 'hot', 'bullish', 'bearish', 'important', 'saved', 'lol']
    if filter is not None and filter in filters:
        url += "&filter={}".format(filter)

    regions = ['en', 'de', 'es', 'fr', 'it', 'pt', 'ru']  # (English), (Deutsch), (Español), (Français), (Italiano), (Português), (Русский)--> Respectively
    if region is not None and region in regions:
        url += "&region={}".format(region)

    if page is not None:
        url += "&page={}".format(page)

    return url


def get_page_json(url=None):
    """
    Get First Page.

    Returns Json.

    """
    time.sleep(global_api_rate_delay)
    if not url:
        url = "https://cryptopanic.com/api/v1/posts/?auth_token={}".format(config.API_KEY)
    page = requests.get(url)
    data = page.json()
    return data


def get_pages_list_json(lookback, url):
    """
    Get history of pages starting from page 1 to the lookback.

    Returns: List of Pages in Json format

    """
    pages_list_json = [get_page_json(url)]

    for i in range(lookback):
        pages_list_json.append(get_page_json(pages_list_json[i]["next"]))

    return pages_list_json

def get_df(data):
    """Return pandas DF."""
    # Ensure that data is a list of dictionaries
    if not all(isinstance(item, dict) for item in data):
        raise ValueError("Data must be a list of dictionaries")
    df = pd.DataFrame(data)
    try:
        df['created_at'] = pd.to_datetime(df['created_at'])
    except Exception as e:
        print(f"An error occurred: {e}")
    return df

def concatenate_pages(pages_list):
    """Concatenate Pages into one Dataframe."""
    # Ensure that pages_list is a list of lists of dictionaries
    if not all(isinstance(page, list) and all(isinstance(item, dict) for item in page) for page in pages_list):
        raise ValueError("Pages list must be a list of lists of dictionaries")
    frames = [get_df(page) for page in pages_list]
    return pd.concat(frames, ignore_index=True)

# The get_last_posts function needs to be updated to pass a list of lists of dictionaries
def get_last_posts(api_key, number_of_posts=200):
    pages_list = []
    page = 1
    total_results = 0
    while total_results < number_of_posts:
        url = make_url(api_key=api_key, filter='important', currencies='BTC', page=page)
        data = get_page_json(url)
        page_results = data['results']
        pages_list.append(page_results)
        total_results += len(page_results)
        page += 1
        if 'next' not in data or not data['next']:
            break  # No more pages to fetch
    # Trim the list to contain exactly the number_of_posts results
    flat_list = [item for sublist in pages_list for item in sublist]
    flat_list = flat_list[:number_of_posts]
    return [flat_list]

# Get the last 200 posts
pages_list = get_last_posts(api_key, number_of_posts=200)
df_last_200_posts = concatenate_pages(pages_list)
print(df_last_200_posts.head())
# Out:
#    kind                 domain  \
# 0  news          dailyhodl.com
# 1  news     cryptobriefing.com
# 2  news                u.today
# 3  news            newsbtc.com
# 4  news  en.bitcoinsistemi.com
#
#                                                votes  \
# 0  {'negative': 0, 'positive': 7, 'important': 4,...
# 1  {'negative': 0, 'positive': 10, 'important': 5...
# 2  {'negative': 0, 'positive': 5, 'important': 3,...
# 3  {'negative': 6, 'positive': 10, 'important': 3...
# 4  {'negative': 1, 'positive': 35, 'important': 1...
#
#                                               source  \
# 0  {'title': 'The Daily Hodl', 'region': 'en', 'd...
# 1  {'title': 'CryptoBriefing', 'region': 'en', 'd...
# 2  {'title': 'U.Today', 'region': 'en', 'domain':...
# 3  {'title': 'NewsBTC', 'region': 'en', 'domain':...
# 4  {'title': 'en bitcoinsistemi', 'region': 'en',...
#
#                                                title          published_at  \
# 0  $100,000,000,000 in TradFi Money Waiting for B...  2023-11-20T19:05:54Z
# 1  ARK Ignores SEC Advice, Refiles In-Kind Bitcoi...  2023-11-20T15:39:10Z
# 2  XRP, BTC, ETH, ADA, SOL Funds Attract More Inf...  2023-11-20T15:39:00Z
# 3  ADA Price (Cardano) Breaking This Confluence R...  2023-11-20T04:28:28Z
# 4  JUST IN: Pro-Bitcoin Candidate Javier Milei Wi...  2023-11-19T23:40:06Z
#
#                                                 slug  \
# 0  100000000000-in-TradFi-Money-Waiting-for-Bitco...
# 1  ARK-Ignores-SEC-Advice-Refiles-In-Kind-Bitcoin...
# 2  XRP-BTC-ETH-ADA-SOL-Funds-Attract-More-Inflows...
# 3  ADA-Price-Cardano-Breaking-This-Confluence-Res...
# 4  JUST-IN-Pro-Bitcoin-Candidate-Javier-Milei-Win...
#
#                                           currencies        id  \
# 0  [{'code': 'BTC', 'title': 'Bitcoin', 'slug': '...  19051010
# 1  [{'code': 'BTC', 'title': 'Bitcoin', 'slug': '...  19050524
# 2  [{'code': 'BTC', 'title': 'Bitcoin', 'slug': '...  19050530
# 3  [{'code': 'BTC', 'title': 'Bitcoin', 'slug': '...  19049104
# 4  [{'code': 'BTC', 'title': 'Bitcoin', 'slug': '...  19048931
#
#                                                  url                created_at
# 0  https://cryptopanic.com/news/19051010/10000000... 2023-11-20 19:05:54+00:00
# 1  https://cryptopanic.com/news/19050524/ARK-Igno... 2023-11-20 15:39:10+00:00
# 2  https://cryptopanic.com/news/19050530/XRP-BTC-... 2023-11-20 15:39:00+00:00
# 3  https://cryptopanic.com/news/19049104/ADA-Pric... 2023-11-20 04:28:28+00:00
# 4  https://cryptopanic.com/news/19048931/JUST-IN-... 2023-11-19 23:40:06+00:00

# %%
df_last_200_posts
# Out:
#      kind                 domain  \
# 0    news          dailyhodl.com
# 1    news     cryptobriefing.com
# 2    news                u.today
# 3    news            newsbtc.com
# 4    news  en.bitcoinsistemi.com
# ..    ...                    ...
# 195  news            finbold.com
# 196  news            finbold.com
# 197  news          dailyhodl.com
# 198  news  en.bitcoinsistemi.com
# 199  news         bitcoinist.com
#
#                                                  votes  \
# 0    {'negative': 0, 'positive': 7, 'important': 4,...
# 1    {'negative': 0, 'positive': 10, 'important': 5...
# 2    {'negative': 0, 'positive': 5, 'important': 3,...
# 3    {'negative': 6, 'positive': 10, 'important': 3...
# 4    {'negative': 1, 'positive': 35, 'important': 1...
# ..                                                 ...
# 195  {'negative': 2, 'positive': 1, 'important': 3,...
# 196  {'negative': 2, 'positive': 4, 'important': 7,...
# 197  {'negative': 1, 'positive': 3, 'important': 3,...
# 198  {'negative': 0, 'positive': 5, 'important': 4,...
# 199  {'negative': 0, 'positive': 7, 'important': 3,...
#
#                                                 source  \
# 0    {'title': 'The Daily Hodl', 'region': 'en', 'd...
# 1    {'title': 'CryptoBriefing', 'region': 'en', 'd...
# 2    {'title': 'U.Today', 'region': 'en', 'domain':...
# 3    {'title': 'NewsBTC', 'region': 'en', 'domain':...
# 4    {'title': 'en bitcoinsistemi', 'region': 'en',...
# ..                                                 ...
# 195  {'title': 'Finbold', 'region': 'en', 'domain':...
# 196  {'title': 'Finbold', 'region': 'en', 'domain':...
# 197  {'title': 'The Daily Hodl', 'region': 'en', 'd...
# 198  {'title': 'en bitcoinsistemi', 'region': 'en',...
# 199  {'title': 'Bitcoinist', 'region': 'en', 'domai...
#
#                                                  title          published_at  \
